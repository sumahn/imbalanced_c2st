# %% [markdown]
# ### Packages

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd

import torch 
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

from sklearn.utils import check_random_state
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from scipy.stats import norm

from utils import c2st_nn_fit, MatConvert, c2st_nn_power
from models import myLDA

from torch.utils.tensorboard import SummaryWriter

# %%
tb_logger = SummaryWriter(log_dir = "/home/oldrain123/log")

# %% [markdown]
# ### Data

# %%
import numpy as np
import pandas as pd

def sample_with_imbalance_2d(a_seq):
    n0 = int(500*a_seq)
    n1 = 500
    mean0 = [0, 0]
    cov0 = [[1, 0], [0, 1]]
    mean1 = [0, 0.5]
    cov1 = [[1, 0], [0, 1]]
    x0 = np.random.multivariate_normal(mean0, cov0, n0)
    x1 = np.random.multivariate_normal(mean1, cov1, n1)
    class0 = np.repeat(0, n0)
    class1 = np.repeat(1, n1)
    x = np.concatenate((np.column_stack((x0, class0)), np.column_stack((x1, class1))))
    np.random.shuffle(x)
    df = pd.DataFrame(x, columns=["x1", "x2", "class"])
    return df

# %% [markdown]
# ### Simulations

# %%
# Setup seeds 
np.random.seed(1203)
torch.manual_seed(1203)
torch.cuda.manual_seed(1203)

torch.backends.cudnn.deterministic = True
is_cuda = True

# Setup for all experiments 
dtype = torch.float
device = torch.device("cuda:2")
alpha = 0.05 # test threshold 
ir_list = [1,3,5,7,9] # imbalance ratio
x_in = 2 # number of neurons in the input layer (dimension of data)
H = 50 # number of neurons in the hidden layer
x_out = 2 # number of neurons in the output layer 
K = 1 # number of experiments
n1 = 100 # size of minority samples

# %%
# For each n in n_list, train deep kernel and run two-sample test
stats_a_dict = {}
stats_d_dict = {}
stats_p_dict = {}

acc_opt_cuts = []
pwr_opt_cuts = []

a_powers = {}
d_powers = {}
p_powers = {}

for r in ir_list:
    np.random.seed(1203)
    N1 = n1 * r
    N2 = n1
    batch_size = N1 + N2 # not using batch 
    n_epoch_c2st = 1200
    
    # Repeat experiments K times (K = 10) and report average test powers
    stats_a_nn = []
    stats_d_nn = []
    stats_p_nn = []
    
    for kk in range(50):
        # print('='*100)
        # print("\t\t\t\tImbalance Ratio: {}".format(int(N1/N2)))
        # print(f"\t\t\t\tExperiments{kk+1}")
        # print('='*100)
        
        np.random.seed(seed=112*kk + 1 + N1)
        data = sample_with_imbalance_2d(r)
        S = data[['x1', 'x2']].values        
        S = MatConvert(S, device, dtype)
        y = MatConvert(data['class'].values, device, dtype)
        
        # Train C2ST-L
        np.random.seed(seed=1203)
        torch.manual_seed(1203)
        torch.cuda.manual_seed(1203)
        cutvals = np.arange(start=0.001, stop=0.999, step = 0.001)
        acc, pwr, acc_opt_cut, pwr_opt_cut = c2st_nn_fit(S, y, x_in, H, x_out, cutvals, 0.01, n_epoch_c2st, batch_size, device, dtype, validation=True)
        acc_opt_cuts.append(acc_opt_cut)
        pwr_opt_cuts.append(pwr_opt_cut)
        # print("-"*100)
        # print('-'*100)
        # print("\t\t\t\t   Testing")
        # print('-'*100)
        # print('-'*100)
        tau0_a, tau1_a, tau0_p, tau1_p, stat_a, stat_d, stat_p = c2st_nn_fit(S, y, x_in, H, x_out, cutvals, 0.01, n_epoch_c2st*2, batch_size, device, dtype, validation=False, acc_opt_cut=acc_opt_cut, pwr_opt_cut=pwr_opt_cut)
        tb_logger.add_scalar('sims/stat_a', stat_a, global_step = kk)
        tb_logger.add_scalar('sims/stat_d', stat_d, global_step = kk)
        tb_logger.add_scalar('sims/stat_p', stat_p, global_step = kk)
        # statistics
        stats_a_nn.append(stat_a)
        stats_d_nn.append(stat_d)
        stats_p_nn.append(stat_p)

    stats_a_dict[r] = stats_a_nn
    stats_d_dict[r] = stats_d_nn
    stats_p_dict[r] = stats_p_nn
    # power
    cr = norm.ppf(1-alpha)
    a_pwr = np.mean((stats_a_nn > (1-norm.ppf(alpha))))
    d_pwr = np.mean((stats_d_nn > (1-norm.ppf(alpha))))
    p_pwr = np.mean((stats_p_nn > (1-norm.ppf(alpha))))
    tb_logger.add_scalar('N_vs_N/a_pwr', a_pwr, global_step = r)
    tb_logger.add_scalar('N_vs_N/d_pwr', d_pwr, global_step = r)
    tb_logger.add_scalar('N_vs_N/p_pwr', p_pwr, global_step = r)
    a_powers[r] = a_pwr
    d_powers[r] = d_pwr
    p_powers[r] = p_pwr
    # print("Accuracy Power: {}".format(a_pwr), '\t', "Default Power: {}".format(d_pwr), '\t', "Power Power: {}".format(p_pwr))
    # print("="*50)
# Out:
# Epochs: 0	Training Binary CE Loss: 0.7554	Validation Binary CE Loss: 0.7553	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6592	Validation Binary CE Loss: 0.6495	Training Accuracy: 0.624	Validation Accuracy: 0.628
# Epochs: 200	Training Binary CE Loss: 0.6265	Validation Binary CE Loss: 0.7171	Training Accuracy: 0.64	Validation Accuracy: 0.64
# Epochs: 300	Training Binary CE Loss: 0.5707	Validation Binary CE Loss: 1.0458	Training Accuracy: 0.672	Validation Accuracy: 0.624
# Epochs: 400	Training Binary CE Loss: 0.5382	Validation Binary CE Loss: 1.4648	Training Accuracy: 0.7	Validation Accuracy: 0.564
# Epochs: 500	Training Binary CE Loss: 0.5038	Validation Binary CE Loss: 2.2306	Training Accuracy: 0.72	Validation Accuracy: 0.548
# Epochs: 600	Training Binary CE Loss: 0.4834	Validation Binary CE Loss: 2.4626	Training Accuracy: 0.736	Validation Accuracy: 0.584
# Epochs: 700	Training Binary CE Loss: 0.5586	Validation Binary CE Loss: 2.4299	Training Accuracy: 0.696	Validation Accuracy: 0.548
# Epochs: 800	Training Binary CE Loss: 0.4508	Validation Binary CE Loss: 3.0192	Training Accuracy: 0.728	Validation Accuracy: 0.54
# Epochs: 900	Training Binary CE Loss: 0.3964	Validation Binary CE Loss: 4.1451	Training Accuracy: 0.784	Validation Accuracy: 0.552
# Epochs: 1000	Training Binary CE Loss: 0.3816	Validation Binary CE Loss: 3.789	Training Accuracy: 0.788	Validation Accuracy: 0.552
# Epochs: 1100	Training Binary CE Loss: 0.3868	Validation Binary CE Loss: 4.7893	Training Accuracy: 0.8	Validation Accuracy: 0.58
# Epochs: 1200	Training Binary CE Loss: 0.3272	Validation Binary CE Loss: 5.6191	Training Accuracy: 0.82	Validation Accuracy: 0.544
# acc_opt_cut:  0.513 	 pwr_opt_cut 0.513
# maximum power of acc_opt_cut:,  1.6850460767745972 	 maximum power of pwr_opt_cut:  1.6850460767745972
# Epochs: 0	Training Binary CE Loss: 0.8127	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6565	Training Accuracy: 0.614
# Epochs: 200	Training Binary CE Loss: 0.652	Training Accuracy: 0.602
# Epochs: 300	Training Binary CE Loss: 0.6501	Training Accuracy: 0.626
# Epochs: 400	Training Binary CE Loss: 0.6347	Training Accuracy: 0.64
# Epochs: 500	Training Binary CE Loss: 0.6242	Training Accuracy: 0.642
# Epochs: 600	Training Binary CE Loss: 0.6058	Training Accuracy: 0.654
# Epochs: 700	Training Binary CE Loss: 0.5823	Training Accuracy: 0.676
# Epochs: 800	Training Binary CE Loss: 0.5724	Training Accuracy: 0.662
# Epochs: 900	Training Binary CE Loss: 0.5279	Training Accuracy: 0.726
# Epochs: 1000	Training Binary CE Loss: 0.5165	Training Accuracy: 0.722
# Epochs: 1100	Training Binary CE Loss: 0.4868	Training Accuracy: 0.74
# Epochs: 1200	Training Binary CE Loss: 0.4683	Training Accuracy: 0.752
# Epochs: 1300	Training Binary CE Loss: 0.4861	Training Accuracy: 0.746
# Epochs: 1400	Training Binary CE Loss: 0.4389	Training Accuracy: 0.758
# Epochs: 1500	Training Binary CE Loss: 0.4397	Training Accuracy: 0.766
# Epochs: 1600	Training Binary CE Loss: 0.4294	Training Accuracy: 0.752
# Epochs: 1700	Training Binary CE Loss: 0.481	Training Accuracy: 0.76
# Epochs: 1800	Training Binary CE Loss: 0.4409	Training Accuracy: 0.738
# Epochs: 1900	Training Binary CE Loss: 0.5898	Training Accuracy: 0.754
# Epochs: 2000	Training Binary CE Loss: 0.5718	Training Accuracy: 0.754
# Epochs: 2100	Training Binary CE Loss: 0.4325	Training Accuracy: 0.75
# Epochs: 2200	Training Binary CE Loss: 0.4187	Training Accuracy: 0.76
# Epochs: 2300	Training Binary CE Loss: 0.4199	Training Accuracy: 0.76
# Epochs: 2400	Training Binary CE Loss: 0.4079	Training Accuracy: 0.766
# Statistics of maximizing acc: 0.18002159893512726 	 tau0_a: 0.4400000274181366 	 tau1_a: 0.5520000457763672
# Statistics of default: 0.09055090695619583 	 tau0_d: 0.42000001668930054 	 tau1_d: 0.5760000348091125
# Statistics of maximizing pwr: 0.18002159893512726 	 tau0_p: 0.4400000274181366 	 tau1_p: 0.5520000457763672
# Epochs: 0	Training Binary CE Loss: 0.7563	Validation Binary CE Loss: 0.7557	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6336	Validation Binary CE Loss: 0.6805	Training Accuracy: 0.62	Validation Accuracy: 0.62
# Epochs: 200	Training Binary CE Loss: 0.6204	Validation Binary CE Loss: 0.7125	Training Accuracy: 0.668	Validation Accuracy: 0.56
# Epochs: 300	Training Binary CE Loss: 0.5838	Validation Binary CE Loss: 0.7785	Training Accuracy: 0.696	Validation Accuracy: 0.54
# Epochs: 400	Training Binary CE Loss: 0.5357	Validation Binary CE Loss: 1.0557	Training Accuracy: 0.704	Validation Accuracy: 0.52
# Epochs: 500	Training Binary CE Loss: 0.507	Validation Binary CE Loss: 1.5703	Training Accuracy: 0.74	Validation Accuracy: 0.532
# Epochs: 600	Training Binary CE Loss: 0.4688	Validation Binary CE Loss: 1.6618	Training Accuracy: 0.756	Validation Accuracy: 0.508
# Epochs: 700	Training Binary CE Loss: 0.4277	Validation Binary CE Loss: 1.9546	Training Accuracy: 0.796	Validation Accuracy: 0.496
# Epochs: 800	Training Binary CE Loss: 0.3907	Validation Binary CE Loss: 2.0007	Training Accuracy: 0.828	Validation Accuracy: 0.54
# Epochs: 900	Training Binary CE Loss: 0.3713	Validation Binary CE Loss: 2.4746	Training Accuracy: 0.816	Validation Accuracy: 0.508
# Epochs: 1000	Training Binary CE Loss: 0.3459	Validation Binary CE Loss: 2.7208	Training Accuracy: 0.848	Validation Accuracy: 0.516
# Epochs: 1100	Training Binary CE Loss: 0.3584	Validation Binary CE Loss: 3.1471	Training Accuracy: 0.836	Validation Accuracy: 0.496
# Epochs: 1200	Training Binary CE Loss: 0.287	Validation Binary CE Loss: 3.3953	Training Accuracy: 0.868	Validation Accuracy: 0.536
# acc_opt_cut:  0.325 	 pwr_opt_cut 0.325
# maximum power of acc_opt_cut:,  2.0908327102661133 	 maximum power of pwr_opt_cut:  2.0908327102661133
# Epochs: 0	Training Binary CE Loss: 0.8072	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.641	Training Accuracy: 0.62
# Epochs: 200	Training Binary CE Loss: 0.6338	Training Accuracy: 0.628
# Epochs: 300	Training Binary CE Loss: 0.6269	Training Accuracy: 0.634
# Epochs: 400	Training Binary CE Loss: 0.6166	Training Accuracy: 0.652
# Epochs: 500	Training Binary CE Loss: 0.5944	Training Accuracy: 0.686
# Epochs: 600	Training Binary CE Loss: 0.5578	Training Accuracy: 0.724
# Epochs: 700	Training Binary CE Loss: 0.5101	Training Accuracy: 0.734
# Epochs: 800	Training Binary CE Loss: 0.4539	Training Accuracy: 0.776
# Epochs: 900	Training Binary CE Loss: 0.4214	Training Accuracy: 0.796
# Epochs: 1000	Training Binary CE Loss: 0.3814	Training Accuracy: 0.82
# Epochs: 1100	Training Binary CE Loss: 0.4043	Training Accuracy: 0.806
# Epochs: 1200	Training Binary CE Loss: 0.3592	Training Accuracy: 0.836
# Epochs: 1300	Training Binary CE Loss: 0.3198	Training Accuracy: 0.854
# Epochs: 1400	Training Binary CE Loss: 0.3166	Training Accuracy: 0.864
# Epochs: 1500	Training Binary CE Loss: 0.3085	Training Accuracy: 0.86
# Epochs: 1600	Training Binary CE Loss: 0.3073	Training Accuracy: 0.872
# Epochs: 1700	Training Binary CE Loss: 0.2915	Training Accuracy: 0.864
# Epochs: 1800	Training Binary CE Loss: 0.336	Training Accuracy: 0.842
# Epochs: 1900	Training Binary CE Loss: 0.2916	Training Accuracy: 0.868
# Epochs: 2000	Training Binary CE Loss: 0.2651	Training Accuracy: 0.87
# Epochs: 2100	Training Binary CE Loss: 0.2807	Training Accuracy: 0.872
# Epochs: 2200	Training Binary CE Loss: 0.2525	Training Accuracy: 0.88
# Epochs: 2300	Training Binary CE Loss: 0.3772	Training Accuracy: 0.842
# Epochs: 2400	Training Binary CE Loss: 0.2306	Training Accuracy: 0.894
# Statistics of maximizing acc: 1.2610243558883667 	 tau0_a: 0.42000001668930054 	 tau1_a: 0.5240000486373901
# Statistics of default: 1.7044625282287598 	 tau0_d: 0.46800002455711365 	 tau1_d: 0.45600003004074097
# Statistics of maximizing pwr: 1.2610243558883667 	 tau0_p: 0.42000001668930054 	 tau1_p: 0.5240000486373901
# Epochs: 0	Training Binary CE Loss: 0.7563	Validation Binary CE Loss: 0.7565	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6379	Validation Binary CE Loss: 0.7211	Training Accuracy: 0.616	Validation Accuracy: 0.592
# Epochs: 200	Training Binary CE Loss: 0.6267	Validation Binary CE Loss: 0.7176	Training Accuracy: 0.62	Validation Accuracy: 0.588
# Epochs: 300	Training Binary CE Loss: 0.601	Validation Binary CE Loss: 0.7697	Training Accuracy: 0.64	Validation Accuracy: 0.548
# Epochs: 400	Training Binary CE Loss: 0.5822	Validation Binary CE Loss: 1.0343	Training Accuracy: 0.68	Validation Accuracy: 0.532
# Epochs: 500	Training Binary CE Loss: 0.5324	Validation Binary CE Loss: 1.3843	Training Accuracy: 0.704	Validation Accuracy: 0.504
# Epochs: 600	Training Binary CE Loss: 0.5035	Validation Binary CE Loss: 1.5365	Training Accuracy: 0.732	Validation Accuracy: 0.552
# Epochs: 700	Training Binary CE Loss: 0.4888	Validation Binary CE Loss: 1.5207	Training Accuracy: 0.736	Validation Accuracy: 0.504
# Epochs: 800	Training Binary CE Loss: 0.4749	Validation Binary CE Loss: 1.9234	Training Accuracy: 0.756	Validation Accuracy: 0.516
# Epochs: 900	Training Binary CE Loss: 0.4782	Validation Binary CE Loss: 1.9138	Training Accuracy: 0.772	Validation Accuracy: 0.508
# Epochs: 1000	Training Binary CE Loss: 0.4303	Validation Binary CE Loss: 2.255	Training Accuracy: 0.792	Validation Accuracy: 0.552
# Epochs: 1100	Training Binary CE Loss: 0.3994	Validation Binary CE Loss: 1.9313	Training Accuracy: 0.804	Validation Accuracy: 0.572
# Epochs: 1200	Training Binary CE Loss: 0.3638	Validation Binary CE Loss: 2.5575	Training Accuracy: 0.8	Validation Accuracy: 0.596
# acc_opt_cut:  0.485 	 pwr_opt_cut 0.864
# maximum power of acc_opt_cut:,  3.2629172801971436 	 maximum power of pwr_opt_cut:  3.4358294010162354
# Epochs: 0	Training Binary CE Loss: 0.8119	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6685	Training Accuracy: 0.588
# Epochs: 200	Training Binary CE Loss: 0.6655	Training Accuracy: 0.606
# Epochs: 300	Training Binary CE Loss: 0.6614	Training Accuracy: 0.602
# Epochs: 400	Training Binary CE Loss: 0.6567	Training Accuracy: 0.604
# Epochs: 500	Training Binary CE Loss: 0.6543	Training Accuracy: 0.596
# Epochs: 600	Training Binary CE Loss: 0.6432	Training Accuracy: 0.602
# Epochs: 700	Training Binary CE Loss: 0.6007	Training Accuracy: 0.638
# Epochs: 800	Training Binary CE Loss: 0.5593	Training Accuracy: 0.68
# Epochs: 900	Training Binary CE Loss: 0.5042	Training Accuracy: 0.7
# Epochs: 1000	Training Binary CE Loss: 0.4734	Training Accuracy: 0.732
# Epochs: 1100	Training Binary CE Loss: 0.4545	Training Accuracy: 0.742
# Epochs: 1200	Training Binary CE Loss: 0.3952	Training Accuracy: 0.78
# Epochs: 1300	Training Binary CE Loss: 0.4195	Training Accuracy: 0.754
# Epochs: 1400	Training Binary CE Loss: 0.4009	Training Accuracy: 0.758
# Epochs: 1500	Training Binary CE Loss: 0.3827	Training Accuracy: 0.762
# Epochs: 1600	Training Binary CE Loss: 0.3178	Training Accuracy: 0.806
# Epochs: 1700	Training Binary CE Loss: 0.3178	Training Accuracy: 0.796
# Epochs: 1800	Training Binary CE Loss: 0.2954	Training Accuracy: 0.794
# Epochs: 1900	Training Binary CE Loss: 0.2866	Training Accuracy: 0.806
# Epochs: 2000	Training Binary CE Loss: 0.2861	Training Accuracy: 0.814
# Epochs: 2100	Training Binary CE Loss: 0.2817	Training Accuracy: 0.798
# Epochs: 2200	Training Binary CE Loss: 0.4429	Training Accuracy: 0.772
# Epochs: 2300	Training Binary CE Loss: 0.3206	Training Accuracy: 0.79
# Epochs: 2400	Training Binary CE Loss: 0.3462	Training Accuracy: 0.79
# Statistics of maximizing acc: 2.350844383239746 	 tau0_a: 0.30400002002716064 	 tau1_a: 0.5960000157356262
# Statistics of default: 4.7076215744018555 	 tau0_d: 0.5560000538825989 	 tau1_d: 0.24800001084804535
# Statistics of maximizing pwr: 4.695774078369141 	 tau0_p: 0.6080000400543213 	 tau1_p: 0.20400001108646393
# Epochs: 0	Training Binary CE Loss: 0.7589	Validation Binary CE Loss: 0.7596	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6468	Validation Binary CE Loss: 0.6611	Training Accuracy: 0.616	Validation Accuracy: 0.568
# Epochs: 200	Training Binary CE Loss: 0.6227	Validation Binary CE Loss: 0.6763	Training Accuracy: 0.652	Validation Accuracy: 0.608
# Epochs: 300	Training Binary CE Loss: 0.5991	Validation Binary CE Loss: 0.7085	Training Accuracy: 0.664	Validation Accuracy: 0.58
# Epochs: 400	Training Binary CE Loss: 0.5888	Validation Binary CE Loss: 0.7318	Training Accuracy: 0.652	Validation Accuracy: 0.528
# Epochs: 500	Training Binary CE Loss: 0.5664	Validation Binary CE Loss: 0.8299	Training Accuracy: 0.66	Validation Accuracy: 0.532
# Epochs: 600	Training Binary CE Loss: 0.5302	Validation Binary CE Loss: 0.9544	Training Accuracy: 0.728	Validation Accuracy: 0.524
# Epochs: 700	Training Binary CE Loss: 0.5195	Validation Binary CE Loss: 1.2215	Training Accuracy: 0.712	Validation Accuracy: 0.492
# Epochs: 800	Training Binary CE Loss: 0.5031	Validation Binary CE Loss: 1.2949	Training Accuracy: 0.736	Validation Accuracy: 0.504
# Epochs: 900	Training Binary CE Loss: 1.2674	Validation Binary CE Loss: 1.4264	Training Accuracy: 0.708	Validation Accuracy: 0.524
# Epochs: 1000	Training Binary CE Loss: 0.4987	Validation Binary CE Loss: 0.9706	Training Accuracy: 0.74	Validation Accuracy: 0.52
# Epochs: 1100	Training Binary CE Loss: 0.4703	Validation Binary CE Loss: 1.293	Training Accuracy: 0.756	Validation Accuracy: 0.52
# Epochs: 1200	Training Binary CE Loss: 0.4459	Validation Binary CE Loss: 1.3922	Training Accuracy: 0.756	Validation Accuracy: 0.512
# acc_opt_cut:  0.917 	 pwr_opt_cut 0.997
# maximum power of acc_opt_cut:,  1.813212513923645 	 maximum power of pwr_opt_cut:  2.619272470474243
# Epochs: 0	Training Binary CE Loss: 0.8097	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6403	Training Accuracy: 0.652
# Epochs: 200	Training Binary CE Loss: 0.6346	Training Accuracy: 0.644
# Epochs: 300	Training Binary CE Loss: 0.6291	Training Accuracy: 0.658
# Epochs: 400	Training Binary CE Loss: 0.6132	Training Accuracy: 0.664
# Epochs: 500	Training Binary CE Loss: 0.5966	Training Accuracy: 0.676
# Epochs: 600	Training Binary CE Loss: 0.5707	Training Accuracy: 0.7
# Epochs: 700	Training Binary CE Loss: 0.5494	Training Accuracy: 0.704
# Epochs: 800	Training Binary CE Loss: 0.526	Training Accuracy: 0.724
# Epochs: 900	Training Binary CE Loss: 0.4813	Training Accuracy: 0.734
# Epochs: 1000	Training Binary CE Loss: 0.4442	Training Accuracy: 0.78
# Epochs: 1100	Training Binary CE Loss: 0.4041	Training Accuracy: 0.802
# Epochs: 1200	Training Binary CE Loss: 0.3391	Training Accuracy: 0.826
# Epochs: 1300	Training Binary CE Loss: 0.2966	Training Accuracy: 0.862
# Epochs: 1400	Training Binary CE Loss: 0.289	Training Accuracy: 0.86
# Epochs: 1500	Training Binary CE Loss: 0.2505	Training Accuracy: 0.89
# Epochs: 1600	Training Binary CE Loss: 0.2352	Training Accuracy: 0.89
# Epochs: 1700	Training Binary CE Loss: 0.4007	Training Accuracy: 0.888
# Epochs: 1800	Training Binary CE Loss: 0.1981	Training Accuracy: 0.906
# Epochs: 1900	Training Binary CE Loss: 0.4019	Training Accuracy: 0.892
# Epochs: 2000	Training Binary CE Loss: 0.3979	Training Accuracy: 0.912
# Epochs: 2100	Training Binary CE Loss: 0.38	Training Accuracy: 0.92
# Epochs: 2200	Training Binary CE Loss: 0.5267	Training Accuracy: 0.852
# Epochs: 2300	Training Binary CE Loss: 0.3857	Training Accuracy: 0.924
# Epochs: 2400	Training Binary CE Loss: 0.4033	Training Accuracy: 0.908
# Statistics of maximizing acc: 1.3098405599594116 	 tau0_a: 0.6160000562667847 	 tau1_a: 0.328000009059906
# Statistics of default: 0.3587473928928375 	 tau0_d: 0.527999997138977 	 tau1_d: 0.45600003004074097
# Statistics of maximizing pwr: 1.3796215057373047 	 tau0_p: 0.6800000071525574 	 tau1_p: 0.2639999985694885
# Epochs: 0	Training Binary CE Loss: 0.7588	Validation Binary CE Loss: 0.7578	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6488	Validation Binary CE Loss: 0.6431	Training Accuracy: 0.636	Validation Accuracy: 0.632
# Epochs: 200	Training Binary CE Loss: 0.6143	Validation Binary CE Loss: 0.6445	Training Accuracy: 0.668	Validation Accuracy: 0.652
# Epochs: 300	Training Binary CE Loss: 0.5846	Validation Binary CE Loss: 0.6774	Training Accuracy: 0.664	Validation Accuracy: 0.636
# Epochs: 400	Training Binary CE Loss: 0.601	Validation Binary CE Loss: 0.649	Training Accuracy: 0.672	Validation Accuracy: 0.636
# Epochs: 500	Training Binary CE Loss: 0.5709	Validation Binary CE Loss: 0.6459	Training Accuracy: 0.68	Validation Accuracy: 0.62
# Epochs: 600	Training Binary CE Loss: 0.5439	Validation Binary CE Loss: 0.741	Training Accuracy: 0.692	Validation Accuracy: 0.624
# Epochs: 700	Training Binary CE Loss: 0.4803	Validation Binary CE Loss: 1.1225	Training Accuracy: 0.732	Validation Accuracy: 0.636
# Epochs: 800	Training Binary CE Loss: 0.458	Validation Binary CE Loss: 1.5283	Training Accuracy: 0.744	Validation Accuracy: 0.612
# Epochs: 900	Training Binary CE Loss: 0.4239	Validation Binary CE Loss: 1.6302	Training Accuracy: 0.768	Validation Accuracy: 0.572
# Epochs: 1000	Training Binary CE Loss: 0.4033	Validation Binary CE Loss: 2.2479	Training Accuracy: 0.792	Validation Accuracy: 0.604
# Epochs: 1100	Training Binary CE Loss: 0.4015	Validation Binary CE Loss: 2.1545	Training Accuracy: 0.788	Validation Accuracy: 0.564
# Epochs: 1200	Training Binary CE Loss: 0.3759	Validation Binary CE Loss: 2.2121	Training Accuracy: 0.78	Validation Accuracy: 0.6
# acc_opt_cut:  0.486 	 pwr_opt_cut 0.864
# maximum power of acc_opt_cut:,  3.8131492137908936 	 maximum power of pwr_opt_cut:  3.98972225189209
# Epochs: 0	Training Binary CE Loss: 0.8101	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6676	Training Accuracy: 0.618
# Epochs: 200	Training Binary CE Loss: 0.6618	Training Accuracy: 0.616
# Epochs: 300	Training Binary CE Loss: 0.6419	Training Accuracy: 0.638
# Epochs: 400	Training Binary CE Loss: 0.6293	Training Accuracy: 0.636
# Epochs: 500	Training Binary CE Loss: 0.6169	Training Accuracy: 0.662
# Epochs: 600	Training Binary CE Loss: 0.5903	Training Accuracy: 0.672
# Epochs: 700	Training Binary CE Loss: 0.5484	Training Accuracy: 0.7
# Epochs: 800	Training Binary CE Loss: 0.5429	Training Accuracy: 0.69
# Epochs: 900	Training Binary CE Loss: 0.4598	Training Accuracy: 0.764
# Epochs: 1000	Training Binary CE Loss: 0.4262	Training Accuracy: 0.786
# Epochs: 1100	Training Binary CE Loss: 0.3873	Training Accuracy: 0.81
# Epochs: 1200	Training Binary CE Loss: 0.3677	Training Accuracy: 0.82
# Epochs: 1300	Training Binary CE Loss: 0.3515	Training Accuracy: 0.818
# Epochs: 1400	Training Binary CE Loss: 0.3638	Training Accuracy: 0.812
# Epochs: 1500	Training Binary CE Loss: 0.3238	Training Accuracy: 0.848
# Epochs: 1600	Training Binary CE Loss: 0.2896	Training Accuracy: 0.862
# Epochs: 1700	Training Binary CE Loss: 0.289	Training Accuracy: 0.856
# Epochs: 1800	Training Binary CE Loss: 0.336	Training Accuracy: 0.814
# Epochs: 1900	Training Binary CE Loss: 0.2811	Training Accuracy: 0.86
# Epochs: 2000	Training Binary CE Loss: 0.279	Training Accuracy: 0.862
# Epochs: 2100	Training Binary CE Loss: 0.2821	Training Accuracy: 0.856
# Epochs: 2200	Training Binary CE Loss: 0.2556	Training Accuracy: 0.882
# Epochs: 2300	Training Binary CE Loss: 0.2687	Training Accuracy: 0.872
# Epochs: 2400	Training Binary CE Loss: 0.2579	Training Accuracy: 0.876
# Statistics of maximizing acc: 1.2582107782363892 	 tau0_a: 0.5120000243186951 	 tau1_a: 0.4320000112056732
# Statistics of default: 1.3488454818725586 	 tau0_d: 0.5120000243186951 	 tau1_d: 0.4280000329017639
# Statistics of maximizing pwr: 0.38753509521484375 	 tau0_p: 0.6840000152587891 	 tau1_p: 0.30000001192092896
# Epochs: 0	Training Binary CE Loss: 0.7575	Validation Binary CE Loss: 0.7589	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6044	Validation Binary CE Loss: 0.7326	Training Accuracy: 0.632	Validation Accuracy: 0.628
# Epochs: 200	Training Binary CE Loss: 0.5707	Validation Binary CE Loss: 1.0988	Training Accuracy: 0.656	Validation Accuracy: 0.608
# Epochs: 300	Training Binary CE Loss: 0.555	Validation Binary CE Loss: 1.1619	Training Accuracy: 0.672	Validation Accuracy: 0.588
# Epochs: 400	Training Binary CE Loss: 0.5167	Validation Binary CE Loss: 1.4833	Training Accuracy: 0.704	Validation Accuracy: 0.588
# Epochs: 500	Training Binary CE Loss: 0.4984	Validation Binary CE Loss: 2.6515	Training Accuracy: 0.7	Validation Accuracy: 0.572
# Epochs: 600	Training Binary CE Loss: 0.4405	Validation Binary CE Loss: 3.8176	Training Accuracy: 0.8	Validation Accuracy: 0.572
# Epochs: 700	Training Binary CE Loss: 0.4068	Validation Binary CE Loss: 3.3907	Training Accuracy: 0.804	Validation Accuracy: 0.592
# Epochs: 800	Training Binary CE Loss: 0.3937	Validation Binary CE Loss: 4.4277	Training Accuracy: 0.82	Validation Accuracy: 0.532
# Epochs: 900	Training Binary CE Loss: 0.3535	Validation Binary CE Loss: 4.5187	Training Accuracy: 0.816	Validation Accuracy: 0.592
# Epochs: 1000	Training Binary CE Loss: 0.3426	Validation Binary CE Loss: 4.9105	Training Accuracy: 0.824	Validation Accuracy: 0.576
# Epochs: 1100	Training Binary CE Loss: 0.3246	Validation Binary CE Loss: 6.1735	Training Accuracy: 0.832	Validation Accuracy: 0.58
# Epochs: 1200	Training Binary CE Loss: 0.3647	Validation Binary CE Loss: 6.418	Training Accuracy: 0.812	Validation Accuracy: 0.544
# acc_opt_cut:  0.768 	 pwr_opt_cut 0.859
# maximum power of acc_opt_cut:,  2.2934470176696777 	 maximum power of pwr_opt_cut:  2.3724875450134277
# Epochs: 0	Training Binary CE Loss: 0.8135	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6795	Training Accuracy: 0.558
# Epochs: 200	Training Binary CE Loss: 0.6618	Training Accuracy: 0.578
# Epochs: 300	Training Binary CE Loss: 0.6444	Training Accuracy: 0.612
# Epochs: 400	Training Binary CE Loss: 0.6286	Training Accuracy: 0.62
# Epochs: 500	Training Binary CE Loss: 0.591	Training Accuracy: 0.65
# Epochs: 600	Training Binary CE Loss: 0.5617	Training Accuracy: 0.67
# Epochs: 700	Training Binary CE Loss: 0.5325	Training Accuracy: 0.704
# Epochs: 800	Training Binary CE Loss: 0.5081	Training Accuracy: 0.734
# Epochs: 900	Training Binary CE Loss: 0.5313	Training Accuracy: 0.728
# Epochs: 1000	Training Binary CE Loss: 0.5885	Training Accuracy: 0.748
# Epochs: 1100	Training Binary CE Loss: 0.4626	Training Accuracy: 0.756
# Epochs: 1200	Training Binary CE Loss: 0.4441	Training Accuracy: 0.766
# Epochs: 1300	Training Binary CE Loss: 0.4472	Training Accuracy: 0.77
# Epochs: 1400	Training Binary CE Loss: 0.4253	Training Accuracy: 0.774
# Epochs: 1500	Training Binary CE Loss: 0.4224	Training Accuracy: 0.786
# Epochs: 1600	Training Binary CE Loss: 0.3897	Training Accuracy: 0.8
# Epochs: 1700	Training Binary CE Loss: 0.3694	Training Accuracy: 0.81
# Epochs: 1800	Training Binary CE Loss: 0.366	Training Accuracy: 0.814
# Epochs: 1900	Training Binary CE Loss: 0.3602	Training Accuracy: 0.818
# Epochs: 2000	Training Binary CE Loss: 0.3767	Training Accuracy: 0.824
# Epochs: 2100	Training Binary CE Loss: 0.379	Training Accuracy: 0.802
# Epochs: 2200	Training Binary CE Loss: 0.3318	Training Accuracy: 0.834
# Epochs: 2300	Training Binary CE Loss: 0.3533	Training Accuracy: 0.832
# Epochs: 2400	Training Binary CE Loss: 0.4958	Training Accuracy: 0.822
# Statistics of maximizing acc: 0.9504945874214172 	 tau0_a: 0.6480000019073486 	 tau1_a: 0.31200000643730164
# Statistics of default: 1.1645631790161133 	 tau0_d: 0.484000027179718 	 tau1_d: 0.46400001645088196
# Statistics of maximizing pwr: 1.814942717552185 	 tau0_p: 0.6920000314712524 	 tau1_p: 0.23600001633167267
# Epochs: 0	Training Binary CE Loss: 0.7605	Validation Binary CE Loss: 0.7626	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6472	Validation Binary CE Loss: 0.6685	Training Accuracy: 0.62	Validation Accuracy: 0.576
# Epochs: 200	Training Binary CE Loss: 0.6109	Validation Binary CE Loss: 0.7421	Training Accuracy: 0.644	Validation Accuracy: 0.516
# Epochs: 300	Training Binary CE Loss: 0.6061	Validation Binary CE Loss: 0.7404	Training Accuracy: 0.656	Validation Accuracy: 0.536
# Epochs: 400	Training Binary CE Loss: 0.5992	Validation Binary CE Loss: 0.7702	Training Accuracy: 0.644	Validation Accuracy: 0.528
# Epochs: 500	Training Binary CE Loss: 0.5852	Validation Binary CE Loss: 0.7378	Training Accuracy: 0.676	Validation Accuracy: 0.52
# Epochs: 600	Training Binary CE Loss: 0.5596	Validation Binary CE Loss: 0.773	Training Accuracy: 0.688	Validation Accuracy: 0.536
# Epochs: 700	Training Binary CE Loss: 0.5383	Validation Binary CE Loss: 0.8642	Training Accuracy: 0.684	Validation Accuracy: 0.532
# Epochs: 800	Training Binary CE Loss: 0.5074	Validation Binary CE Loss: 1.0254	Training Accuracy: 0.716	Validation Accuracy: 0.536
# Epochs: 900	Training Binary CE Loss: 0.4667	Validation Binary CE Loss: 2.165	Training Accuracy: 0.744	Validation Accuracy: 0.552
# Epochs: 1000	Training Binary CE Loss: 0.4671	Validation Binary CE Loss: 2.8454	Training Accuracy: 0.736	Validation Accuracy: 0.536
# Epochs: 1100	Training Binary CE Loss: 0.439	Validation Binary CE Loss: 3.8766	Training Accuracy: 0.74	Validation Accuracy: 0.544
# Epochs: 1200	Training Binary CE Loss: 0.4203	Validation Binary CE Loss: 4.6694	Training Accuracy: 0.756	Validation Accuracy: 0.572
# acc_opt_cut:  0.47000000000000003 	 pwr_opt_cut 0.11
# maximum power of acc_opt_cut:,  2.8543038368225098 	 maximum power of pwr_opt_cut:  3.0048859119415283
# Epochs: 0	Training Binary CE Loss: 0.8087	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6608	Training Accuracy: 0.608
# Epochs: 200	Training Binary CE Loss: 0.6546	Training Accuracy: 0.618
# Epochs: 300	Training Binary CE Loss: 0.6534	Training Accuracy: 0.612
# Epochs: 400	Training Binary CE Loss: 0.6386	Training Accuracy: 0.646
# Epochs: 500	Training Binary CE Loss: 0.6198	Training Accuracy: 0.658
# Epochs: 600	Training Binary CE Loss: 0.6093	Training Accuracy: 0.67
# Epochs: 700	Training Binary CE Loss: 0.6	Training Accuracy: 0.674
# Epochs: 800	Training Binary CE Loss: 0.5799	Training Accuracy: 0.686
# Epochs: 900	Training Binary CE Loss: 0.5757	Training Accuracy: 0.684
# Epochs: 1000	Training Binary CE Loss: 0.5545	Training Accuracy: 0.71
# Epochs: 1100	Training Binary CE Loss: 0.5439	Training Accuracy: 0.71
# Epochs: 1200	Training Binary CE Loss: 0.5348	Training Accuracy: 0.736
# Epochs: 1300	Training Binary CE Loss: 0.5311	Training Accuracy: 0.732
# Epochs: 1400	Training Binary CE Loss: 0.5327	Training Accuracy: 0.734
# Epochs: 1500	Training Binary CE Loss: 0.5263	Training Accuracy: 0.732
# Epochs: 1600	Training Binary CE Loss: 0.5247	Training Accuracy: 0.742
# Epochs: 1700	Training Binary CE Loss: 0.5205	Training Accuracy: 0.738
# Epochs: 1800	Training Binary CE Loss: 0.4963	Training Accuracy: 0.758
# Epochs: 1900	Training Binary CE Loss: 0.4955	Training Accuracy: 0.752
# Epochs: 2000	Training Binary CE Loss: 0.5052	Training Accuracy: 0.75
# Epochs: 2100	Training Binary CE Loss: 0.4982	Training Accuracy: 0.75
# Epochs: 2200	Training Binary CE Loss: 0.4869	Training Accuracy: 0.774
# Epochs: 2300	Training Binary CE Loss: 0.4836	Training Accuracy: 0.762
# Epochs: 2400	Training Binary CE Loss: 0.4858	Training Accuracy: 0.76
# Statistics of maximizing acc: 3.3634681701660156 	 tau0_a: 0.3760000169277191 	 tau1_a: 0.47600001096725464
# Statistics of default: 3.3495469093322754 	 tau0_d: 0.40400001406669617 	 tau1_d: 0.4480000138282776
# Statistics of maximizing pwr: 0.6596638560295105 	 tau0_p: 0.07200000435113907 	 tau1_p: 0.9120000600814819
# Epochs: 0	Training Binary CE Loss: 0.7613	Validation Binary CE Loss: 0.7619	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6688	Validation Binary CE Loss: 0.6853	Training Accuracy: 0.568	Validation Accuracy: 0.564
# Epochs: 200	Training Binary CE Loss: 0.659	Validation Binary CE Loss: 0.7054	Training Accuracy: 0.6	Validation Accuracy: 0.544
# Epochs: 300	Training Binary CE Loss: 0.6378	Validation Binary CE Loss: 0.7156	Training Accuracy: 0.636	Validation Accuracy: 0.572
# Epochs: 400	Training Binary CE Loss: 0.6038	Validation Binary CE Loss: 0.8493	Training Accuracy: 0.656	Validation Accuracy: 0.532
# Epochs: 500	Training Binary CE Loss: 0.5522	Validation Binary CE Loss: 0.9291	Training Accuracy: 0.684	Validation Accuracy: 0.516
# Epochs: 600	Training Binary CE Loss: 0.5303	Validation Binary CE Loss: 1.0108	Training Accuracy: 0.684	Validation Accuracy: 0.52
# Epochs: 700	Training Binary CE Loss: 0.5311	Validation Binary CE Loss: 1.1406	Training Accuracy: 0.7	Validation Accuracy: 0.548
# Epochs: 800	Training Binary CE Loss: 0.4764	Validation Binary CE Loss: 1.5451	Training Accuracy: 0.728	Validation Accuracy: 0.532
# Epochs: 900	Training Binary CE Loss: 0.4855	Validation Binary CE Loss: 2.0365	Training Accuracy: 0.728	Validation Accuracy: 0.564
# Epochs: 1000	Training Binary CE Loss: 0.4582	Validation Binary CE Loss: 2.1664	Training Accuracy: 0.732	Validation Accuracy: 0.58
# Epochs: 1100	Training Binary CE Loss: 0.4432	Validation Binary CE Loss: 2.4776	Training Accuracy: 0.76	Validation Accuracy: 0.568
# Epochs: 1200	Training Binary CE Loss: 0.3779	Validation Binary CE Loss: 3.4843	Training Accuracy: 0.78	Validation Accuracy: 0.54
# acc_opt_cut:  0.363 	 pwr_opt_cut 0.363
# maximum power of acc_opt_cut:,  2.887148141860962 	 maximum power of pwr_opt_cut:  2.887148141860962
# Epochs: 0	Training Binary CE Loss: 0.811	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6639	Training Accuracy: 0.598
# Epochs: 200	Training Binary CE Loss: 0.655	Training Accuracy: 0.598
# Epochs: 300	Training Binary CE Loss: 0.6385	Training Accuracy: 0.62
# Epochs: 400	Training Binary CE Loss: 0.6259	Training Accuracy: 0.644
# Epochs: 500	Training Binary CE Loss: 0.6161	Training Accuracy: 0.646
# Epochs: 600	Training Binary CE Loss: 0.5893	Training Accuracy: 0.672
# Epochs: 700	Training Binary CE Loss: 0.5606	Training Accuracy: 0.7
# Epochs: 800	Training Binary CE Loss: 0.5142	Training Accuracy: 0.73
# Epochs: 900	Training Binary CE Loss: 0.4743	Training Accuracy: 0.75
# Epochs: 1000	Training Binary CE Loss: 0.4488	Training Accuracy: 0.786
# Epochs: 1100	Training Binary CE Loss: 0.4329	Training Accuracy: 0.77
# Epochs: 1200	Training Binary CE Loss: 0.408	Training Accuracy: 0.802
# Epochs: 1300	Training Binary CE Loss: 0.3922	Training Accuracy: 0.782
# Epochs: 1400	Training Binary CE Loss: 0.388	Training Accuracy: 0.81
# Epochs: 1500	Training Binary CE Loss: 0.4642	Training Accuracy: 0.776
# Epochs: 1600	Training Binary CE Loss: 0.36	Training Accuracy: 0.816
# Epochs: 1700	Training Binary CE Loss: 0.3355	Training Accuracy: 0.83
# Epochs: 1800	Training Binary CE Loss: 0.3535	Training Accuracy: 0.818
# Epochs: 1900	Training Binary CE Loss: 0.3704	Training Accuracy: 0.822
# Epochs: 2000	Training Binary CE Loss: 0.3835	Training Accuracy: 0.834
# Epochs: 2100	Training Binary CE Loss: 0.3623	Training Accuracy: 0.828
# Epochs: 2200	Training Binary CE Loss: 0.3092	Training Accuracy: 0.846
# Epochs: 2300	Training Binary CE Loss: 0.3121	Training Accuracy: 0.838
# Epochs: 2400	Training Binary CE Loss: 0.2789	Training Accuracy: 0.856
# Statistics of maximizing acc: 1.9880094528198242 	 tau0_a: 0.4000000059604645 	 tau1_a: 0.5120000243186951
# Statistics of default: 2.6162452697753906 	 tau0_d: 0.47200003266334534 	 tau1_d: 0.41200003027915955
# Statistics of maximizing pwr: 1.9880094528198242 	 tau0_p: 0.4000000059604645 	 tau1_p: 0.5120000243186951
# Epochs: 0	Training Binary CE Loss: 0.7585	Validation Binary CE Loss: 0.7575	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6518	Validation Binary CE Loss: 0.6693	Training Accuracy: 0.628	Validation Accuracy: 0.64
# Epochs: 200	Training Binary CE Loss: 0.6297	Validation Binary CE Loss: 0.686	Training Accuracy: 0.612	Validation Accuracy: 0.58
# Epochs: 300	Training Binary CE Loss: 0.6006	Validation Binary CE Loss: 0.8607	Training Accuracy: 0.644	Validation Accuracy: 0.596
# Epochs: 400	Training Binary CE Loss: 0.5815	Validation Binary CE Loss: 1.6984	Training Accuracy: 0.648	Validation Accuracy: 0.616
# Epochs: 500	Training Binary CE Loss: 0.5421	Validation Binary CE Loss: 1.9245	Training Accuracy: 0.692	Validation Accuracy: 0.588
# Epochs: 600	Training Binary CE Loss: 0.549	Validation Binary CE Loss: 1.4554	Training Accuracy: 0.7	Validation Accuracy: 0.568
# Epochs: 700	Training Binary CE Loss: 0.4649	Validation Binary CE Loss: 2.0749	Training Accuracy: 0.768	Validation Accuracy: 0.592
# Epochs: 800	Training Binary CE Loss: 0.4113	Validation Binary CE Loss: 3.3443	Training Accuracy: 0.788	Validation Accuracy: 0.56
# Epochs: 900	Training Binary CE Loss: 0.4039	Validation Binary CE Loss: 4.1481	Training Accuracy: 0.792	Validation Accuracy: 0.544
# Epochs: 1000	Training Binary CE Loss: 0.3801	Validation Binary CE Loss: 4.7533	Training Accuracy: 0.792	Validation Accuracy: 0.552
# Epochs: 1100	Training Binary CE Loss: 0.7757	Validation Binary CE Loss: 4.573	Training Accuracy: 0.672	Validation Accuracy: 0.52
# Epochs: 1200	Training Binary CE Loss: 0.3508	Validation Binary CE Loss: 6.2886	Training Accuracy: 0.816	Validation Accuracy: 0.488
# acc_opt_cut:  0.333 	 pwr_opt_cut 0.333
# maximum power of acc_opt_cut:,  1.4667960405349731 	 maximum power of pwr_opt_cut:  1.4667960405349731
# Epochs: 0	Training Binary CE Loss: 0.8104	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6582	Training Accuracy: 0.594
# Epochs: 200	Training Binary CE Loss: 0.6464	Training Accuracy: 0.618
# Epochs: 300	Training Binary CE Loss: 0.6433	Training Accuracy: 0.624
# Epochs: 400	Training Binary CE Loss: 0.6301	Training Accuracy: 0.636
# Epochs: 500	Training Binary CE Loss: 0.6145	Training Accuracy: 0.662
# Epochs: 600	Training Binary CE Loss: 0.5874	Training Accuracy: 0.686
# Epochs: 700	Training Binary CE Loss: 0.546	Training Accuracy: 0.714
# Epochs: 800	Training Binary CE Loss: 0.5333	Training Accuracy: 0.716
# Epochs: 900	Training Binary CE Loss: 0.5179	Training Accuracy: 0.722
# Epochs: 1000	Training Binary CE Loss: 0.4806	Training Accuracy: 0.76
# Epochs: 1100	Training Binary CE Loss: 0.4502	Training Accuracy: 0.776
# Epochs: 1200	Training Binary CE Loss: 0.4438	Training Accuracy: 0.784
# Epochs: 1300	Training Binary CE Loss: 0.4004	Training Accuracy: 0.824
# Epochs: 1400	Training Binary CE Loss: 0.3915	Training Accuracy: 0.798
# Epochs: 1500	Training Binary CE Loss: 0.373	Training Accuracy: 0.818
# Epochs: 1600	Training Binary CE Loss: 0.3447	Training Accuracy: 0.834
# Epochs: 1700	Training Binary CE Loss: 0.515	Training Accuracy: 0.818
# Epochs: 1800	Training Binary CE Loss: 0.5403	Training Accuracy: 0.802
# Epochs: 1900	Training Binary CE Loss: 0.4883	Training Accuracy: 0.854
# Epochs: 2000	Training Binary CE Loss: 0.4651	Training Accuracy: 0.842
# Epochs: 2100	Training Binary CE Loss: 0.457	Training Accuracy: 0.848
# Epochs: 2200	Training Binary CE Loss: 0.4626	Training Accuracy: 0.846
# Epochs: 2300	Training Binary CE Loss: 0.4512	Training Accuracy: 0.848
# Epochs: 2400	Training Binary CE Loss: 0.4416	Training Accuracy: 0.86
# Statistics of maximizing acc: 0.36785396933555603 	 tau0_a: 0.3760000169277191 	 tau1_a: 0.6080000400543213
# Statistics of default: 0.8109875321388245 	 tau0_d: 0.5400000214576721 	 tau1_d: 0.4240000247955322
# Statistics of maximizing pwr: 0.36785396933555603 	 tau0_p: 0.3760000169277191 	 tau1_p: 0.6080000400543213
# Epochs: 0	Training Binary CE Loss: 0.7571	Validation Binary CE Loss: 0.7582	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6531	Validation Binary CE Loss: 0.6549	Training Accuracy: 0.612	Validation Accuracy: 0.604
# Epochs: 200	Training Binary CE Loss: 0.6483	Validation Binary CE Loss: 0.6747	Training Accuracy: 0.636	Validation Accuracy: 0.588
# Epochs: 300	Training Binary CE Loss: 0.631	Validation Binary CE Loss: 0.6811	Training Accuracy: 0.64	Validation Accuracy: 0.6
# Epochs: 400	Training Binary CE Loss: 0.6202	Validation Binary CE Loss: 0.7203	Training Accuracy: 0.636	Validation Accuracy: 0.592
# Epochs: 500	Training Binary CE Loss: 0.6012	Validation Binary CE Loss: 0.7863	Training Accuracy: 0.664	Validation Accuracy: 0.556
# Epochs: 600	Training Binary CE Loss: 0.5511	Validation Binary CE Loss: 1.4374	Training Accuracy: 0.688	Validation Accuracy: 0.556
# Epochs: 700	Training Binary CE Loss: 0.5095	Validation Binary CE Loss: 2.5825	Training Accuracy: 0.696	Validation Accuracy: 0.532
# Epochs: 800	Training Binary CE Loss: 0.4725	Validation Binary CE Loss: 3.123	Training Accuracy: 0.736	Validation Accuracy: 0.524
# Epochs: 900	Training Binary CE Loss: 0.4737	Validation Binary CE Loss: 3.0387	Training Accuracy: 0.736	Validation Accuracy: 0.568
# Epochs: 1000	Training Binary CE Loss: 0.4394	Validation Binary CE Loss: 3.7062	Training Accuracy: 0.756	Validation Accuracy: 0.572
# Epochs: 1100	Training Binary CE Loss: 0.4475	Validation Binary CE Loss: 3.643	Training Accuracy: 0.756	Validation Accuracy: 0.552
# Epochs: 1200	Training Binary CE Loss: 0.4146	Validation Binary CE Loss: 4.239	Training Accuracy: 0.764	Validation Accuracy: 0.556
# acc_opt_cut:  0.587 	 pwr_opt_cut 0.991
# maximum power of acc_opt_cut:,  2.964108943939209 	 maximum power of pwr_opt_cut:  3.227485418319702
# Epochs: 0	Training Binary CE Loss: 0.8103	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6454	Training Accuracy: 0.612
# Epochs: 200	Training Binary CE Loss: 0.6378	Training Accuracy: 0.618
# Epochs: 300	Training Binary CE Loss: 0.6197	Training Accuracy: 0.648
# Epochs: 400	Training Binary CE Loss: 0.5992	Training Accuracy: 0.656
# Epochs: 500	Training Binary CE Loss: 0.5814	Training Accuracy: 0.67
# Epochs: 600	Training Binary CE Loss: 0.5618	Training Accuracy: 0.678
# Epochs: 700	Training Binary CE Loss: 0.5492	Training Accuracy: 0.69
# Epochs: 800	Training Binary CE Loss: 0.5229	Training Accuracy: 0.716
# Epochs: 900	Training Binary CE Loss: 0.5131	Training Accuracy: 0.73
# Epochs: 1000	Training Binary CE Loss: 0.4863	Training Accuracy: 0.744
# Epochs: 1100	Training Binary CE Loss: 0.4651	Training Accuracy: 0.77
# Epochs: 1200	Training Binary CE Loss: 0.4557	Training Accuracy: 0.76
# Epochs: 1300	Training Binary CE Loss: 0.4204	Training Accuracy: 0.794
# Epochs: 1400	Training Binary CE Loss: 0.4509	Training Accuracy: 0.74
# Epochs: 1500	Training Binary CE Loss: 0.4067	Training Accuracy: 0.782
# Epochs: 1600	Training Binary CE Loss: 0.373	Training Accuracy: 0.814
# Epochs: 1700	Training Binary CE Loss: 0.3475	Training Accuracy: 0.82
# Epochs: 1800	Training Binary CE Loss: 0.3257	Training Accuracy: 0.834
# Epochs: 1900	Training Binary CE Loss: 0.3429	Training Accuracy: 0.83
# Epochs: 2000	Training Binary CE Loss: 0.338	Training Accuracy: 0.83
# Epochs: 2100	Training Binary CE Loss: 0.2989	Training Accuracy: 0.86
# Epochs: 2200	Training Binary CE Loss: 0.3079	Training Accuracy: 0.858
# Epochs: 2300	Training Binary CE Loss: 0.2933	Training Accuracy: 0.86
# Epochs: 2400	Training Binary CE Loss: 0.2762	Training Accuracy: 0.882
# Statistics of maximizing acc: 1.4369810819625854 	 tau0_a: 0.5 	 tau1_a: 0.4360000193119049
# Statistics of default: 1.8849726915359497 	 tau0_d: 0.46000000834465027 	 tau1_d: 0.45600003004074097
# Statistics of maximizing pwr: 2.008938789367676 	 tau0_p: 0.6840000152587891 	 tau1_p: 0.23600001633167267
# Epochs: 0	Training Binary CE Loss: 0.7548	Validation Binary CE Loss: 0.7535	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6275	Validation Binary CE Loss: 0.6748	Training Accuracy: 0.64	Validation Accuracy: 0.596
# Epochs: 200	Training Binary CE Loss: 0.6198	Validation Binary CE Loss: 0.6991	Training Accuracy: 0.648	Validation Accuracy: 0.576
# Epochs: 300	Training Binary CE Loss: 0.5651	Validation Binary CE Loss: 0.9392	Training Accuracy: 0.688	Validation Accuracy: 0.532
# Epochs: 400	Training Binary CE Loss: 0.5396	Validation Binary CE Loss: 1.4751	Training Accuracy: 0.7	Validation Accuracy: 0.56
# Epochs: 500	Training Binary CE Loss: 0.5109	Validation Binary CE Loss: 2.2216	Training Accuracy: 0.736	Validation Accuracy: 0.528
# Epochs: 600	Training Binary CE Loss: 0.4556	Validation Binary CE Loss: 2.8861	Training Accuracy: 0.756	Validation Accuracy: 0.536
# Epochs: 700	Training Binary CE Loss: 0.4036	Validation Binary CE Loss: 3.5533	Training Accuracy: 0.804	Validation Accuracy: 0.488
# Epochs: 800	Training Binary CE Loss: 0.3685	Validation Binary CE Loss: 5.2973	Training Accuracy: 0.824	Validation Accuracy: 0.484
# Epochs: 900	Training Binary CE Loss: 0.3399	Validation Binary CE Loss: 5.334	Training Accuracy: 0.824	Validation Accuracy: 0.508
# Epochs: 1000	Training Binary CE Loss: 0.3586	Validation Binary CE Loss: 3.7793	Training Accuracy: 0.824	Validation Accuracy: 0.524
# Epochs: 1100	Training Binary CE Loss: 0.3336	Validation Binary CE Loss: 4.4852	Training Accuracy: 0.824	Validation Accuracy: 0.496
# Epochs: 1200	Training Binary CE Loss: 0.3591	Validation Binary CE Loss: 3.4624	Training Accuracy: 0.824	Validation Accuracy: 0.496
# acc_opt_cut:  0.001 	 pwr_opt_cut 0.001
# maximum power of acc_opt_cut:,  3.0614700317382812 	 maximum power of pwr_opt_cut:  3.0614700317382812
# Epochs: 0	Training Binary CE Loss: 0.8114	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6624	Training Accuracy: 0.618
# Epochs: 200	Training Binary CE Loss: 0.646	Training Accuracy: 0.626
# Epochs: 300	Training Binary CE Loss: 0.6321	Training Accuracy: 0.628
# Epochs: 400	Training Binary CE Loss: 0.62	Training Accuracy: 0.65
# Epochs: 500	Training Binary CE Loss: 0.6091	Training Accuracy: 0.66
# Epochs: 600	Training Binary CE Loss: 0.5996	Training Accuracy: 0.672
# Epochs: 700	Training Binary CE Loss: 0.5864	Training Accuracy: 0.672
# Epochs: 800	Training Binary CE Loss: 0.5734	Training Accuracy: 0.684
# Epochs: 900	Training Binary CE Loss: 0.5623	Training Accuracy: 0.686
# Epochs: 1000	Training Binary CE Loss: 0.5463	Training Accuracy: 0.684
# Epochs: 1100	Training Binary CE Loss: 0.5315	Training Accuracy: 0.706
# Epochs: 1200	Training Binary CE Loss: 0.5101	Training Accuracy: 0.716
# Epochs: 1300	Training Binary CE Loss: 0.4651	Training Accuracy: 0.746
# Epochs: 1400	Training Binary CE Loss: 0.4498	Training Accuracy: 0.762
# Epochs: 1500	Training Binary CE Loss: 0.4226	Training Accuracy: 0.774
# Epochs: 1600	Training Binary CE Loss: 0.424	Training Accuracy: 0.78
# Epochs: 1700	Training Binary CE Loss: 0.4113	Training Accuracy: 0.78
# Epochs: 1800	Training Binary CE Loss: 0.5102	Training Accuracy: 0.764
# Epochs: 1900	Training Binary CE Loss: 0.3712	Training Accuracy: 0.804
# Epochs: 2000	Training Binary CE Loss: 0.3661	Training Accuracy: 0.806
# Epochs: 2100	Training Binary CE Loss: 0.3602	Training Accuracy: 0.808
# Epochs: 2200	Training Binary CE Loss: 0.3543	Training Accuracy: 0.804
# Epochs: 2300	Training Binary CE Loss: 0.3603	Training Accuracy: 0.806
# Epochs: 2400	Training Binary CE Loss: 0.4214	Training Accuracy: 0.786
# Statistics of maximizing acc: 0.0 	 tau0_a: 0.04800000041723251 	 tau1_a: 0.9520000219345093
# Statistics of default: 3.489558696746826 	 tau0_d: 0.5080000162124634 	 tau1_d: 0.3400000035762787
# Statistics of maximizing pwr: 0.0 	 tau0_p: 0.04800000041723251 	 tau1_p: 0.9520000219345093
# Epochs: 0	Training Binary CE Loss: 0.7568	Validation Binary CE Loss: 0.7564	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6734	Validation Binary CE Loss: 0.6648	Training Accuracy: 0.568	Validation Accuracy: 0.616
# Epochs: 200	Training Binary CE Loss: 0.6568	Validation Binary CE Loss: 0.6672	Training Accuracy: 0.6	Validation Accuracy: 0.632
# Epochs: 300	Training Binary CE Loss: 0.6224	Validation Binary CE Loss: 0.7484	Training Accuracy: 0.64	Validation Accuracy: 0.636
# Epochs: 400	Training Binary CE Loss: 0.5899	Validation Binary CE Loss: 0.8517	Training Accuracy: 0.684	Validation Accuracy: 0.592
# Epochs: 500	Training Binary CE Loss: 0.5036	Validation Binary CE Loss: 1.0743	Training Accuracy: 0.724	Validation Accuracy: 0.54
# Epochs: 600	Training Binary CE Loss: 0.4457	Validation Binary CE Loss: 1.7966	Training Accuracy: 0.76	Validation Accuracy: 0.568
# Epochs: 700	Training Binary CE Loss: 0.4723	Validation Binary CE Loss: 2.5779	Training Accuracy: 0.748	Validation Accuracy: 0.552
# Epochs: 800	Training Binary CE Loss: 0.3833	Validation Binary CE Loss: 4.078	Training Accuracy: 0.812	Validation Accuracy: 0.516
# Epochs: 900	Training Binary CE Loss: 0.3566	Validation Binary CE Loss: 3.4104	Training Accuracy: 0.824	Validation Accuracy: 0.568

# %%
ir_list
# Out:
# [1, 3, 5, 7, 9]

# %%
a_powers = {1:0.18, 3:0.02, 5:0.04, 7:0.00, 9:0.0}
p_powers = {1:0.16, 3:0.18, 5:0.34, 7:0.42, 9:0.38}
d_powers = {1:0.34, 3:0.14, 5:0.08, 7:0.1, 9:0.2}

import seaborn as sns
import matplotlib.pyplot as plt

data_a = []
data_p = []
data_d = []
for r in ir_list:
    data_a.append({'imbalance_ratio': r, 'power': a_powers[r]})
    data_p.append({'imbalance_ratio': r, 'power': p_powers[r]})
    data_d.append({'imbalance_ratio': r, 'power': d_powers[r]})
    
        
df_a = pd.DataFrame(data_a)
df_p = pd.DataFrame(data_p)
df_d = pd.DataFrame(data_d)
# Create the plotNo
sns.set_style("whitegrid")
sns.lineplot(data=df_a, x="imbalance_ratio", y="power", label='Max Acc')
sns.lineplot(data=df_p, x="imbalance_ratio", y="power", label='Max Pwr')
sns.lineplot(data=df_d, x="imbalance_ratio", y="power", label='Default')

# Add axis labels and a title
plt.xlabel("Imbalance Ratio")
plt.ylabel("Power")
plt.title("Mean Differnece between Normal")
plt.legend()
# Show the plot
plt.show()

# %%
# For each n in n_list, train deep kernel and run two-sample test
stats_a_dict = {}
stats_d_dict = {}
stats_p_dict = {}

acc_opt_cuts = []
pwr_opt_cuts = []

a_powers = {}
d_powers = {}
p_powers = {}

for r in ir_list:
    np.random.seed(1203)
    N1 = n1 * r
    N2 = n1
    batch_size = N1 + N2 # not using batch 
    n_epoch_c2st = 1000
    
    # Repeat experiments K times (K = 10) and report average test powers
    stats_a = []
    stats_d = []
    stats_p = []
    
    for kk in range(K):
        print('='*100)
        print("\t\t\t\tImbalance Ratio: {}".format(int(N1/N2)))
        print(f"\t\t\t\tExperiments{kk+1}")
        print('='*100)
        # Generate Blob-D
        np.random.seed(seed=112*kk + 1 + N1)
        s1, s2 = sample_blobs_Q(N1, N2, sigma_mx2)
        
        if kk == 0:
            s1_o = s1
            s2_o = s2
        
        S = np.concatenate((s1,s2), axis=0)
        S = MatConvert(S, device, dtype)
        
        # Train C2ST-L
        np.random.seed(seed=1203)
        torch.manual_seed(1203)
        torch.cuda.manual_seed(1203)
        y = (torch.cat((torch.zeros(N1, 1), torch.ones(N2, 1)), 0)).squeeze(1).to(device, dtype).long()
        cutvals = np.linspace(0.001, 0.999, 1000)
        pred, tau0, tau1, stat_c2st = c2st_nn_power(S, y, x_in, H, x_out, 0.01, n_epoch_c2st, batch_size, device, dtype)
# Out:
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments1
# ====================================================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3384955/178449240.py in <module>
#      30         # Generate Blob-D
#      31         np.random.seed(seed=112*kk + 1 + N1)
# ---> 32         s1, s2 = sample_blobs_Q(N1, N2, sigma_mx2)
#      33
#      34         if kk == 0:
#
# NameError: name 'sample_blobs_Q' is not defined

# %%
# For each n in n_list, train deep kernel and run two-sample test

stats = {}
powers = []
for n in n_list:
    np.random.seed(12203)
    torch.manual_seed(12203)
    torch.cuda.manual_seed(12203)
    N1 = 30 * n
    N2 = 300
    results = np.zeros([5, K])
    J_star_adp = np.zeros([K, n_epoch])
    batch_size = N1 + N2 
    n_epoch_c2st = 500
    
    # Repeat experiments K times (K = 10) and report average test power 
    stat = []
    for kk in range(K):
        print("Imbalance Ratio: {}".format(N1/N2))
        print(f"{kk+1} Experiments...")
        
        # Generate Blob-D
        np.random.seed(seed=112*kk + 1 + n)
        s1, s2 = sample_blobs_Q(N1, N2, sigma_mx2)
        
        if kk == 0:
            s1_o = s1
            s2_o = s2
        
        S = np.concatenate((s1,s2), axis=0)
        S = MatConvert(S, device, dtype)
        
        # Train C2ST-L
        np.random.seed(seed=12203)
        torch.manual_seed(12203)
        torch.cuda.manual_seed(12203)
        y = (torch.cat((torch.zeros(N1, 1), torch.ones(N2, 1)), 0)).squeeze(1).to(device, dtype).long()
        pred, tau0, tau1, stat_c2st_l, model_c2st_l, w_c2st_l, b_c2st_l = C2ST_NN_power(S, y, N1, x_in, H, x_out, 0.0005, 
                                                                          n_epoch_c2st, batch_size, device, dtype)
        # statistics
        stat.append(stat_c2st_l)
        print(pred.unique(return_counts=True))
        print(f"tau0: {tau0} \t tau1: {tau1} ", end='\t')
        print("Stats: {}".format(stat_c2st_l))
        stats[n] = stat
        
    # power
    pwr = len([i for i in stats[n] if i > (1-norm.ppf(alpha))]) / len(stats[n])
    powers.append(pwr)
    print("Power: {}".format(pwr))
    print("="*50)

# %%
stats

# %%
tau1

# %%
stat_c2st_l

# %%
pred.unique(return_counts=True)

# %%
stats

# %%
batch_size = 32

df = sample_blobs_Q(500, 500, sigma_mx2)

# %%
# Generate data
data = sample_blobs_Q(n0=500, n1=500, sigma_mx_2=sigma_mx2)

# Split data into training and test sets
train_data = data.sample(frac=0.8, random_state=42)
test_data = data.drop(train_data.index)

# Convert data to PyTorch tensors
train_x = torch.tensor(train_data.iloc[:, :-1].values, dtype=torch.float32)
train_y = torch.tensor(train_data.iloc[:, -1].values, dtype=torch.int64)
test_x = torch.tensor(test_data.iloc[:, :-1].values, dtype=torch.float32)
test_y = torch.tensor(test_data.iloc[:, -1].values, dtype=torch.int64)

# Define the LeNet model
model = LeNet()

# Define the optimizer and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = torch.nn.CrossEntropyLoss()

# Train the model
num_epochs = 10
for epoch in range(num_epochs):
    # Shuffle the training data
    indices = torch.randperm(train_x.shape[0])
    train_x = train_x[indices]
    train_y = train_y[indices]
    
    # Train the model for one epoch
    model.train()
    for i in range(0, train_x.shape[0], batch_size):
        # Get the current batch of training data
        x = train_x[i:i+batch_size].reshape(-1, 1, 2, 1)
        y = train_y[i:i+batch_size]
        
        # Zero the gradients
        optimizer.zero_grad()
        
        # Forward pass
        y_pred = model(x)
        loss = loss_fn(y_pred, y)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()

# %%
# X_train, X_test, y_train, y_test = train_test_split(df.drop("class", axis=1), df["class"], test_size=0.5, random_state=42)
# X_train = torch.from_numpy(X_train.to_numpy().reshape(-1, 1, 3, 3)).float()
# y_train = torch.from_numpy(y_train.to_numpy()).float()
# X_test = torch.from_numpy(X_test.to_numpy().reshape(-1, 1, 3, 3)).float()
# y_test = torch.from_numpy(y_test.to_numpy()).float()

# %%
model = LeNet()
optimizer = optim.Adam(model.parameters(), lr = 0.001)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size)

# %%
num_epochs = 10
criterion = nn.CrossEntropyLoss()
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
    print(f"Epoch {epoch+1}, loss: {running_loss/len(train_loader)}")

# %%
# set up training parameters
learning_rate = 0.001
num_epochs = 10
batch_size = 128

# define the loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# train the model
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        # inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels.float())
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print('[Epoch %d] Loss: %.3f' % (epoch + 1, running_loss / len(train_loader)))

# predict on the test set
model.eval()
y_pred = []
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        y_pred.append(outputs.detach().cpu().numpy().flatten())
y_pred = np.concatenate(y_pred)

# compute power function
tau_0 = np.mean(y_test[y_test == 0])
tau_1 = np.mean(y_test[y_test == 1])
n0 = len(y_test[y_test == 0])
n1 = len(y_test[y_test == 1])
sigma_mx_2 = get_sigma_mx2(n0, n1, y_test, y_pred)
se = np.sqrt(tau_1*(1-tau_1)/n1 + tau_0*(1-tau_0)/n0)
power = norm.cdf((norm.ppf(0.8) - se*np.sqrt(sigma_mx_2.sum()))/np.sqrt(sigma_mx_2.sum()))
print('Power:', power)
