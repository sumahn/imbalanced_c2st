# %% [markdown]
# ### Packages

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd

import torch 
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

from sklearn.utils import check_random_state
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from scipy.stats import norm

from utils import c2st_nn_fit, MatConvert, c2st_nn_power
from models import myLDA

# %% [markdown]
# ### Data

# %%
import numpy as np
import pandas as pd

def sample_with_imbalance_2d(a_seq):
    n0 = int(500*a_seq)
    n1 = 500
    mean0 = [0, 0]
    cov0 = [[1, 0], [0, 1]]
    x0 = np.random.multivariate_normal(mean0, cov0, n0)
    x1 = np.column_stack((np.random.standard_t(3, n1), np.random.standard_t(3, n1)))
    class0 = np.repeat(0, n0)
    class1 = np.repeat(1, n1)
    x = np.concatenate((np.column_stack((x0, class0)), np.column_stack((x1, class1))))
    np.random.shuffle(x)
    df = pd.DataFrame(x, columns=["x1", "x2", "class"])
    return df

# %% [markdown]
# ### Simulations

# %%
# Setup seeds 
np.random.seed(1203)
torch.manual_seed(1203)
torch.cuda.manual_seed(1203)

torch.backends.cudnn.deterministic = True
is_cuda = True

# Setup for all experiments 
dtype = torch.float
device = torch.device("cuda:1")
alpha = 0.05 # test threshold 
ir_list = [1,3,5,7,9] # imbalance ratio
x_in = 2 # number of neurons in the input layer (dimension of data)
H = 50 # number of neurons in the hidden layer
x_out = 2 # number of neurons in the output layer 
K = 1 # number of experiments
n1 = 100 # size of minority samples

# %%
# For each n in n_list, train deep kernel and run two-sample test
stats_a_dict = {}
stats_d_dict = {}
stats_p_dict = {}

acc_opt_cuts = []
pwr_opt_cuts = []

a_powers = {}
d_powers = {}
p_powers = {}

for r in ir_list:
    np.random.seed(1203)
    N1 = n1 * r
    N2 = n1
    batch_size = N1 + N2 # not using batch 
    n_epoch_c2st = 1200
    
    # Repeat experiments K times (K = 10) and report average test powers
    stats_a_nn = []
    stats_d_nn = []
    stats_p_nn = []
    
    for kk in range(50):
        print('='*100)
        print("\t\t\t\tImbalance Ratio: {}".format(int(N1/N2)))
        print(f"\t\t\t\tExperiments{kk+1}")
        print('='*100)
        
        np.random.seed(seed=112*kk + 1 + N1)
        data = sample_with_imbalance_2d(r)
        S = data[['x1', 'x2']].values        
        S = MatConvert(S, device, dtype)
        y = MatConvert(data['class'].values, device, dtype)
        
        # Train C2ST-L
        np.random.seed(seed=1203)
        torch.manual_seed(1203)
        torch.cuda.manual_seed(1203)
        cutvals = np.arange(start=0.001, stop=0.999, step = 0.001)
        acc, pwr, acc_opt_cut, pwr_opt_cut = c2st_nn_fit(S, y, x_in, H, x_out, cutvals, 0.01, n_epoch_c2st, batch_size, device, dtype, validation=True)
        acc_opt_cuts.append(acc_opt_cut)
        pwr_opt_cuts.append(pwr_opt_cut)
        print("-"*100)
        print('-'*100)
        print("\t\t\t\t   Testing")
        print('-'*100)
        print('-'*100)
        tau0_a, tau1_a, tau0_p, tau1_p, stat_a, stat_d, stat_p = c2st_nn_fit(S, y, x_in, H, x_out, cutvals, 0.01, n_epoch_c2st*2, batch_size, device, dtype, validation=False, acc_opt_cut=acc_opt_cut, pwr_opt_cut=pwr_opt_cut)
        
        # statistics
        stats_a_nn.append(stat_a)
        stats_d_nn.append(stat_d)
        stats_p_nn.append(stat_p)

    stats_a_dict[r] = stats_a_nn
    stats_d_dict[r] = stats_d_nn
    stats_p_dict[r] = stats_p_nn
    # power
    cr = norm.ppf(1-alpha)
    a_pwr = np.mean((stats_a_nn > (1-norm.ppf(alpha))))
    d_pwr = np.mean((stats_d_nn > (1-norm.ppf(alpha))))
    p_pwr = np.mean((stats_p_nn > (1-norm.ppf(alpha))))
    
    a_powers[r] = a_pwr
    d_powers[r] = d_pwr
    p_powers[r] = p_pwr
    print("Accuracy Power: {}".format(a_pwr), '\t', "Default Power: {}".format(d_pwr), '\t', "Power Power: {}".format(p_pwr))
    print("="*50)
# Out:
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments1
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7546	Validation Binary CE Loss: 0.75	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6362	Validation Binary CE Loss: 0.6553	Training Accuracy: 0.604	Validation Accuracy: 0.548
# Epochs: 200	Training Binary CE Loss: 0.5858	Validation Binary CE Loss: 0.684	Training Accuracy: 0.652	Validation Accuracy: 0.564
# Epochs: 300	Training Binary CE Loss: 0.5443	Validation Binary CE Loss: 0.8172	Training Accuracy: 0.696	Validation Accuracy: 0.552
# Epochs: 400	Training Binary CE Loss: 0.5369	Validation Binary CE Loss: 1.4197	Training Accuracy: 0.676	Validation Accuracy: 0.5
# Epochs: 500	Training Binary CE Loss: 0.5157	Validation Binary CE Loss: 1.4679	Training Accuracy: 0.712	Validation Accuracy: 0.556
# Epochs: 600	Training Binary CE Loss: 0.4767	Validation Binary CE Loss: 1.86	Training Accuracy: 0.728	Validation Accuracy: 0.56
# Epochs: 700	Training Binary CE Loss: 0.5059	Validation Binary CE Loss: 1.7249	Training Accuracy: 0.712	Validation Accuracy: 0.52
# Epochs: 800	Training Binary CE Loss: 0.4567	Validation Binary CE Loss: 2.3088	Training Accuracy: 0.716	Validation Accuracy: 0.544
# Epochs: 900	Training Binary CE Loss: 0.4384	Validation Binary CE Loss: 2.6001	Training Accuracy: 0.732	Validation Accuracy: 0.548
# Epochs: 1000	Training Binary CE Loss: 0.4178	Validation Binary CE Loss: 2.8278	Training Accuracy: 0.752	Validation Accuracy: 0.544
# Epochs: 1100	Training Binary CE Loss: 0.4259	Validation Binary CE Loss: 3.7265	Training Accuracy: 0.76	Validation Accuracy: 0.54
# Epochs: 1200	Training Binary CE Loss: 0.4112	Validation Binary CE Loss: 3.4759	Training Accuracy: 0.752	Validation Accuracy: 0.544
# acc_opt_cut:  0.011 	 pwr_opt_cut 0.011
# maximum power of acc_opt_cut:,  3.1669726371765137 	 maximum power of pwr_opt_cut:  3.1669726371765137
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8088	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6402	Training Accuracy: 0.58
# Epochs: 200	Training Binary CE Loss: 0.6239	Training Accuracy: 0.614
# Epochs: 300	Training Binary CE Loss: 0.6095	Training Accuracy: 0.612
# Epochs: 400	Training Binary CE Loss: 0.585	Training Accuracy: 0.648
# Epochs: 500	Training Binary CE Loss: 0.5597	Training Accuracy: 0.678
# Epochs: 600	Training Binary CE Loss: 0.5116	Training Accuracy: 0.732
# Epochs: 700	Training Binary CE Loss: 0.4731	Training Accuracy: 0.742
# Epochs: 800	Training Binary CE Loss: 0.4411	Training Accuracy: 0.768
# Epochs: 900	Training Binary CE Loss: 0.4056	Training Accuracy: 0.774
# Epochs: 1000	Training Binary CE Loss: 0.3797	Training Accuracy: 0.798
# Epochs: 1100	Training Binary CE Loss: 0.3609	Training Accuracy: 0.814
# Epochs: 1200	Training Binary CE Loss: 0.3221	Training Accuracy: 0.838
# Epochs: 1300	Training Binary CE Loss: 0.3396	Training Accuracy: 0.82
# Epochs: 1400	Training Binary CE Loss: 0.2951	Training Accuracy: 0.842
# Epochs: 1500	Training Binary CE Loss: 0.2418	Training Accuracy: 0.876
# Epochs: 1600	Training Binary CE Loss: 0.2206	Training Accuracy: 0.89
# Epochs: 1700	Training Binary CE Loss: 0.2039	Training Accuracy: 0.896
# Epochs: 1800	Training Binary CE Loss: 0.2012	Training Accuracy: 0.896
# Epochs: 1900	Training Binary CE Loss: 0.2964	Training Accuracy: 0.852
# Epochs: 2000	Training Binary CE Loss: 0.1855	Training Accuracy: 0.906
# Epochs: 2100	Training Binary CE Loss: 0.2327	Training Accuracy: 0.866
# Epochs: 2200	Training Binary CE Loss: 0.2062	Training Accuracy: 0.892
# Epochs: 2300	Training Binary CE Loss: 0.1759	Training Accuracy: 0.904
# Epochs: 2400	Training Binary CE Loss: 0.1643	Training Accuracy: 0.916
# Statistics of maximizing acc: 2.585038185119629 	 tau0_a: 0.2760000228881836 	 tau1_a: 0.6160000562667847
# Statistics of default: 1.70600163936615 	 tau0_d: 0.484000027179718 	 tau1_d: 0.4400000274181366
# Statistics of maximizing pwr: 2.585038185119629 	 tau0_p: 0.2760000228881836 	 tau1_p: 0.6160000562667847
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments2
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7505	Validation Binary CE Loss: 0.7523	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6163	Validation Binary CE Loss: 0.6608	Training Accuracy: 0.624	Validation Accuracy: 0.544
# Epochs: 200	Training Binary CE Loss: 0.5903	Validation Binary CE Loss: 0.7847	Training Accuracy: 0.624	Validation Accuracy: 0.568
# Epochs: 300	Training Binary CE Loss: 0.5669	Validation Binary CE Loss: 1.7658	Training Accuracy: 0.636	Validation Accuracy: 0.576
# Epochs: 400	Training Binary CE Loss: 0.5393	Validation Binary CE Loss: 2.0961	Training Accuracy: 0.696	Validation Accuracy: 0.548
# Epochs: 500	Training Binary CE Loss: 0.4899	Validation Binary CE Loss: 2.1922	Training Accuracy: 0.74	Validation Accuracy: 0.548
# Epochs: 600	Training Binary CE Loss: 0.5944	Validation Binary CE Loss: 0.7261	Training Accuracy: 0.652	Validation Accuracy: 0.544
# Epochs: 700	Training Binary CE Loss: 0.5293	Validation Binary CE Loss: 1.5906	Training Accuracy: 0.692	Validation Accuracy: 0.548
# Epochs: 800	Training Binary CE Loss: 0.4988	Validation Binary CE Loss: 2.3628	Training Accuracy: 0.748	Validation Accuracy: 0.492
# Epochs: 900	Training Binary CE Loss: 0.4998	Validation Binary CE Loss: 2.4187	Training Accuracy: 0.732	Validation Accuracy: 0.516
# Epochs: 1000	Training Binary CE Loss: 0.4618	Validation Binary CE Loss: 2.6605	Training Accuracy: 0.76	Validation Accuracy: 0.524
# Epochs: 1100	Training Binary CE Loss: 0.447	Validation Binary CE Loss: 2.1196	Training Accuracy: 0.776	Validation Accuracy: 0.532
# Epochs: 1200	Training Binary CE Loss: 0.4199	Validation Binary CE Loss: 3.428	Training Accuracy: 0.8	Validation Accuracy: 0.532
# acc_opt_cut:  0.001 	 pwr_opt_cut 0.001
# maximum power of acc_opt_cut:,  3.3339736461639404 	 maximum power of pwr_opt_cut:  3.3339736461639404
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8152	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6284	Training Accuracy: 0.6
# Epochs: 200	Training Binary CE Loss: 0.6263	Training Accuracy: 0.596
# Epochs: 300	Training Binary CE Loss: 0.6188	Training Accuracy: 0.612
# Epochs: 400	Training Binary CE Loss: 0.6159	Training Accuracy: 0.624
# Epochs: 500	Training Binary CE Loss: 0.6029	Training Accuracy: 0.64
# Epochs: 600	Training Binary CE Loss: 0.5901	Training Accuracy: 0.656
# Epochs: 700	Training Binary CE Loss: 0.556	Training Accuracy: 0.684
# Epochs: 800	Training Binary CE Loss: 0.5295	Training Accuracy: 0.67
# Epochs: 900	Training Binary CE Loss: 0.4934	Training Accuracy: 0.728
# Epochs: 1000	Training Binary CE Loss: 0.4568	Training Accuracy: 0.762
# Epochs: 1100	Training Binary CE Loss: 0.4276	Training Accuracy: 0.766
# Epochs: 1200	Training Binary CE Loss: 0.462	Training Accuracy: 0.75
# Epochs: 1300	Training Binary CE Loss: 0.3676	Training Accuracy: 0.812
# Epochs: 1400	Training Binary CE Loss: 0.3406	Training Accuracy: 0.834
# Epochs: 1500	Training Binary CE Loss: 0.5867	Training Accuracy: 0.792
# Epochs: 1600	Training Binary CE Loss: 0.5201	Training Accuracy: 0.834
# Epochs: 1700	Training Binary CE Loss: 0.5218	Training Accuracy: 0.83
# Epochs: 1800	Training Binary CE Loss: 0.5267	Training Accuracy: 0.83
# Epochs: 1900	Training Binary CE Loss: 0.5036	Training Accuracy: 0.848
# Epochs: 2000	Training Binary CE Loss: 0.5017	Training Accuracy: 0.85
# Epochs: 2100	Training Binary CE Loss: 0.5047	Training Accuracy: 0.84
# Epochs: 2200	Training Binary CE Loss: 0.4555	Training Accuracy: 0.87
# Epochs: 2300	Training Binary CE Loss: 0.4419	Training Accuracy: 0.882
# Epochs: 2400	Training Binary CE Loss: 0.4549	Training Accuracy: 0.874
# Statistics of maximizing acc: 3.054640054702759 	 tau0_a: 0.12800000607967377 	 tau1_a: 0.7680000066757202
# Statistics of default: 1.9919155836105347 	 tau0_d: 0.5200000405311584 	 tau1_d: 0.3920000195503235
# Statistics of maximizing pwr: 3.054640054702759 	 tau0_p: 0.12800000607967377 	 tau1_p: 0.7680000066757202
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments3
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7544	Validation Binary CE Loss: 0.7573	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6501	Validation Binary CE Loss: 0.6979	Training Accuracy: 0.612	Validation Accuracy: 0.528
# Epochs: 200	Training Binary CE Loss: 0.6403	Validation Binary CE Loss: 0.8112	Training Accuracy: 0.644	Validation Accuracy: 0.552
# Epochs: 300	Training Binary CE Loss: 0.5553	Validation Binary CE Loss: 1.2758	Training Accuracy: 0.648	Validation Accuracy: 0.552
# Epochs: 400	Training Binary CE Loss: 0.5297	Validation Binary CE Loss: 1.8433	Training Accuracy: 0.7	Validation Accuracy: 0.516
# Epochs: 500	Training Binary CE Loss: 0.5428	Validation Binary CE Loss: 0.8713	Training Accuracy: 0.692	Validation Accuracy: 0.552
# Epochs: 600	Training Binary CE Loss: 0.519	Validation Binary CE Loss: 1.2094	Training Accuracy: 0.708	Validation Accuracy: 0.556
# Epochs: 700	Training Binary CE Loss: 0.4907	Validation Binary CE Loss: 1.5091	Training Accuracy: 0.724	Validation Accuracy: 0.552
# Epochs: 800	Training Binary CE Loss: 0.507	Validation Binary CE Loss: 2.2878	Training Accuracy: 0.736	Validation Accuracy: 0.532
# Epochs: 900	Training Binary CE Loss: 0.4349	Validation Binary CE Loss: 2.3203	Training Accuracy: 0.788	Validation Accuracy: 0.552
# Epochs: 1000	Training Binary CE Loss: 1.6178	Validation Binary CE Loss: 1.9389	Training Accuracy: 0.684	Validation Accuracy: 0.54
# Epochs: 1100	Training Binary CE Loss: 1.6384	Validation Binary CE Loss: 3.3954	Training Accuracy: 0.752	Validation Accuracy: 0.528
# Epochs: 1200	Training Binary CE Loss: 1.6126	Validation Binary CE Loss: 4.0389	Training Accuracy: 0.76	Validation Accuracy: 0.504
# acc_opt_cut:  0.05 	 pwr_opt_cut 0.002
# maximum power of acc_opt_cut:,  3.3362996578216553 	 maximum power of pwr_opt_cut:  3.5925350189208984
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8209	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6369	Training Accuracy: 0.61
# Epochs: 200	Training Binary CE Loss: 0.6191	Training Accuracy: 0.642
# Epochs: 300	Training Binary CE Loss: 0.6012	Training Accuracy: 0.654
# Epochs: 400	Training Binary CE Loss: 0.5941	Training Accuracy: 0.646
# Epochs: 500	Training Binary CE Loss: 0.5759	Training Accuracy: 0.664
# Epochs: 600	Training Binary CE Loss: 0.5342	Training Accuracy: 0.706
# Epochs: 700	Training Binary CE Loss: 0.5182	Training Accuracy: 0.72
# Epochs: 800	Training Binary CE Loss: 0.4432	Training Accuracy: 0.76
# Epochs: 900	Training Binary CE Loss: 0.4167	Training Accuracy: 0.774
# Epochs: 1000	Training Binary CE Loss: 0.4224	Training Accuracy: 0.782
# Epochs: 1100	Training Binary CE Loss: 0.3631	Training Accuracy: 0.816
# Epochs: 1200	Training Binary CE Loss: 0.3623	Training Accuracy: 0.82
# Epochs: 1300	Training Binary CE Loss: 0.3257	Training Accuracy: 0.83
# Epochs: 1400	Training Binary CE Loss: 0.3175	Training Accuracy: 0.834
# Epochs: 1500	Training Binary CE Loss: 0.297	Training Accuracy: 0.858
# Epochs: 1600	Training Binary CE Loss: 0.2871	Training Accuracy: 0.85
# Epochs: 1700	Training Binary CE Loss: 0.2802	Training Accuracy: 0.874
# Epochs: 1800	Training Binary CE Loss: 0.2782	Training Accuracy: 0.868
# Epochs: 1900	Training Binary CE Loss: 0.2686	Training Accuracy: 0.862
# Epochs: 2000	Training Binary CE Loss: 0.2714	Training Accuracy: 0.87
# Epochs: 2100	Training Binary CE Loss: 0.2369	Training Accuracy: 0.888
# Epochs: 2200	Training Binary CE Loss: 0.233	Training Accuracy: 0.898
# Epochs: 2300	Training Binary CE Loss: 0.2149	Training Accuracy: 0.902
# Epochs: 2400	Training Binary CE Loss: 0.2529	Training Accuracy: 0.872
# Statistics of maximizing acc: 1.4405014514923096 	 tau0_a: 0.18000000715255737 	 tau1_a: 0.7680000066757202
# Statistics of default: 0.7177720069885254 	 tau0_d: 0.4480000138282776 	 tau1_d: 0.5200000405311584
# Statistics of maximizing pwr: 2.3698112964630127 	 tau0_p: 0.08400000631809235 	 tau1_p: 0.8480000495910645
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments4
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7401	Validation Binary CE Loss: 0.7412	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6124	Validation Binary CE Loss: 0.6928	Training Accuracy: 0.616	Validation Accuracy: 0.6
# Epochs: 200	Training Binary CE Loss: 0.5969	Validation Binary CE Loss: 0.7459	Training Accuracy: 0.612	Validation Accuracy: 0.588
# Epochs: 300	Training Binary CE Loss: 0.5678	Validation Binary CE Loss: 1.2712	Training Accuracy: 0.664	Validation Accuracy: 0.596
# Epochs: 400	Training Binary CE Loss: 0.5395	Validation Binary CE Loss: 1.3724	Training Accuracy: 0.696	Validation Accuracy: 0.64
# Epochs: 500	Training Binary CE Loss: 0.4822	Validation Binary CE Loss: 1.7186	Training Accuracy: 0.732	Validation Accuracy: 0.62
# Epochs: 600	Training Binary CE Loss: 0.4651	Validation Binary CE Loss: 2.1938	Training Accuracy: 0.724	Validation Accuracy: 0.616
# Epochs: 700	Training Binary CE Loss: 0.4172	Validation Binary CE Loss: 2.8703	Training Accuracy: 0.752	Validation Accuracy: 0.608
# Epochs: 800	Training Binary CE Loss: 0.443	Validation Binary CE Loss: 2.7397	Training Accuracy: 0.744	Validation Accuracy: 0.636
# Epochs: 900	Training Binary CE Loss: 0.3885	Validation Binary CE Loss: 4.0851	Training Accuracy: 0.776	Validation Accuracy: 0.612
# Epochs: 1000	Training Binary CE Loss: 0.4077	Validation Binary CE Loss: 5.1454	Training Accuracy: 0.768	Validation Accuracy: 0.588
# Epochs: 1100	Training Binary CE Loss: 0.6899	Validation Binary CE Loss: 6.0743	Training Accuracy: 0.776	Validation Accuracy: 0.62
# Epochs: 1200	Training Binary CE Loss: 0.3682	Validation Binary CE Loss: 3.9784	Training Accuracy: 0.764	Validation Accuracy: 0.58
# acc_opt_cut:  0.075 	 pwr_opt_cut 0.075
# maximum power of acc_opt_cut:,  4.978512287139893 	 maximum power of pwr_opt_cut:  4.978512287139893
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8109	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6267	Training Accuracy: 0.6
# Epochs: 200	Training Binary CE Loss: 0.6205	Training Accuracy: 0.634
# Epochs: 300	Training Binary CE Loss: 0.597	Training Accuracy: 0.662
# Epochs: 400	Training Binary CE Loss: 0.5524	Training Accuracy: 0.686
# Epochs: 500	Training Binary CE Loss: 0.5047	Training Accuracy: 0.716
# Epochs: 600	Training Binary CE Loss: 0.5012	Training Accuracy: 0.732
# Epochs: 700	Training Binary CE Loss: 0.4502	Training Accuracy: 0.76
# Epochs: 800	Training Binary CE Loss: 0.4348	Training Accuracy: 0.752
# Epochs: 900	Training Binary CE Loss: 0.4024	Training Accuracy: 0.788
# Epochs: 1000	Training Binary CE Loss: 0.3922	Training Accuracy: 0.792
# Epochs: 1100	Training Binary CE Loss: 0.376	Training Accuracy: 0.806
# Epochs: 1200	Training Binary CE Loss: 0.3679	Training Accuracy: 0.81
# Epochs: 1300	Training Binary CE Loss: 0.3422	Training Accuracy: 0.83
# Epochs: 1400	Training Binary CE Loss: 0.3434	Training Accuracy: 0.838
# Epochs: 1500	Training Binary CE Loss: 0.5126	Training Accuracy: 0.838
# Epochs: 1600	Training Binary CE Loss: 0.3135	Training Accuracy: 0.842
# Epochs: 1700	Training Binary CE Loss: 0.3503	Training Accuracy: 0.818
# Epochs: 1800	Training Binary CE Loss: 0.3012	Training Accuracy: 0.842
# Epochs: 1900	Training Binary CE Loss: 0.2998	Training Accuracy: 0.848
# Epochs: 2000	Training Binary CE Loss: 0.3186	Training Accuracy: 0.83
# Epochs: 2100	Training Binary CE Loss: 0.2838	Training Accuracy: 0.852
# Epochs: 2200	Training Binary CE Loss: 0.2657	Training Accuracy: 0.87
# Epochs: 2300	Training Binary CE Loss: 0.2784	Training Accuracy: 0.872
# Epochs: 2400	Training Binary CE Loss: 0.2559	Training Accuracy: 0.888
# Statistics of maximizing acc: 3.443848133087158 	 tau0_a: 0.14800000190734863 	 tau1_a: 0.7280000448226929
# Statistics of default: 2.3384909629821777 	 tau0_d: 0.4400000274181366 	 tau1_d: 0.45600003004074097
# Statistics of maximizing pwr: 3.443848133087158 	 tau0_p: 0.14800000190734863 	 tau1_p: 0.7280000448226929
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments5
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7676	Validation Binary CE Loss: 0.7685	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6344	Validation Binary CE Loss: 0.6902	Training Accuracy: 0.628	Validation Accuracy: 0.536
# Epochs: 200	Training Binary CE Loss: 0.6041	Validation Binary CE Loss: 0.7203	Training Accuracy: 0.656	Validation Accuracy: 0.524
# Epochs: 300	Training Binary CE Loss: 0.5708	Validation Binary CE Loss: 0.8259	Training Accuracy: 0.684	Validation Accuracy: 0.472
# Epochs: 400	Training Binary CE Loss: 0.5435	Validation Binary CE Loss: 0.873	Training Accuracy: 0.692	Validation Accuracy: 0.512
# Epochs: 500	Training Binary CE Loss: 0.5249	Validation Binary CE Loss: 0.9352	Training Accuracy: 0.72	Validation Accuracy: 0.528
# Epochs: 600	Training Binary CE Loss: 0.4938	Validation Binary CE Loss: 1.0604	Training Accuracy: 0.716	Validation Accuracy: 0.496
# Epochs: 700	Training Binary CE Loss: 0.4763	Validation Binary CE Loss: 1.5457	Training Accuracy: 0.716	Validation Accuracy: 0.532
# Epochs: 800	Training Binary CE Loss: 0.4515	Validation Binary CE Loss: 1.6702	Training Accuracy: 0.76	Validation Accuracy: 0.532
# Epochs: 900	Training Binary CE Loss: 0.421	Validation Binary CE Loss: 2.454	Training Accuracy: 0.776	Validation Accuracy: 0.548
# Epochs: 1000	Training Binary CE Loss: 0.3781	Validation Binary CE Loss: 2.8886	Training Accuracy: 0.812	Validation Accuracy: 0.548
# Epochs: 1100	Training Binary CE Loss: 0.3536	Validation Binary CE Loss: 3.5221	Training Accuracy: 0.812	Validation Accuracy: 0.548
# Epochs: 1200	Training Binary CE Loss: 0.4357	Validation Binary CE Loss: 4.9204	Training Accuracy: 0.796	Validation Accuracy: 0.544
# acc_opt_cut:  0.002 	 pwr_opt_cut 0.002
# maximum power of acc_opt_cut:,  2.6479029655456543 	 maximum power of pwr_opt_cut:  2.6479029655456543
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8098	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6169	Training Accuracy: 0.62
# Epochs: 200	Training Binary CE Loss: 0.6052	Training Accuracy: 0.622
# Epochs: 300	Training Binary CE Loss: 0.6006	Training Accuracy: 0.652
# Epochs: 400	Training Binary CE Loss: 0.5914	Training Accuracy: 0.644
# Epochs: 500	Training Binary CE Loss: 0.5779	Training Accuracy: 0.648
# Epochs: 600	Training Binary CE Loss: 0.5632	Training Accuracy: 0.668
# Epochs: 700	Training Binary CE Loss: 0.5199	Training Accuracy: 0.698
# Epochs: 800	Training Binary CE Loss: 0.4871	Training Accuracy: 0.722
# Epochs: 900	Training Binary CE Loss: 0.4486	Training Accuracy: 0.754
# Epochs: 1000	Training Binary CE Loss: 0.4108	Training Accuracy: 0.792
# Epochs: 1100	Training Binary CE Loss: 0.4382	Training Accuracy: 0.792
# Epochs: 1200	Training Binary CE Loss: 0.3575	Training Accuracy: 0.82
# Epochs: 1300	Training Binary CE Loss: 0.324	Training Accuracy: 0.84
# Epochs: 1400	Training Binary CE Loss: 0.3266	Training Accuracy: 0.838
# Epochs: 1500	Training Binary CE Loss: 0.3389	Training Accuracy: 0.846
# Epochs: 1600	Training Binary CE Loss: 0.3336	Training Accuracy: 0.846
# Epochs: 1700	Training Binary CE Loss: 0.2942	Training Accuracy: 0.85
# Epochs: 1800	Training Binary CE Loss: 0.2573	Training Accuracy: 0.87
# Epochs: 1900	Training Binary CE Loss: 0.3127	Training Accuracy: 0.852
# Epochs: 2000	Training Binary CE Loss: 0.2679	Training Accuracy: 0.864
# Epochs: 2100	Training Binary CE Loss: 0.235	Training Accuracy: 0.9
# Epochs: 2200	Training Binary CE Loss: 0.248	Training Accuracy: 0.88
# Epochs: 2300	Training Binary CE Loss: 0.2246	Training Accuracy: 0.888
# Epochs: 2400	Training Binary CE Loss: 0.3492	Training Accuracy: 0.83
# Statistics of maximizing acc: 2.6786932945251465 	 tau0_a: 0.10400000214576721 	 tau1_a: 0.812000036239624
# Statistics of default: 0.2699250876903534 	 tau0_d: 0.5480000376701355 	 tau1_d: 0.4400000274181366
# Statistics of maximizing pwr: 2.6786932945251465 	 tau0_p: 0.10400000214576721 	 tau1_p: 0.812000036239624
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments6
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7479	Validation Binary CE Loss: 0.7491	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6447	Validation Binary CE Loss: 0.6511	Training Accuracy: 0.564	Validation Accuracy: 0.584
# Epochs: 200	Training Binary CE Loss: 0.6357	Validation Binary CE Loss: 0.6489	Training Accuracy: 0.596	Validation Accuracy: 0.596
# Epochs: 300	Training Binary CE Loss: 0.6156	Validation Binary CE Loss: 0.7043	Training Accuracy: 0.604	Validation Accuracy: 0.552
# Epochs: 400	Training Binary CE Loss: 0.589	Validation Binary CE Loss: 0.79	Training Accuracy: 0.648	Validation Accuracy: 0.588
# Epochs: 500	Training Binary CE Loss: 0.5637	Validation Binary CE Loss: 1.1187	Training Accuracy: 0.684	Validation Accuracy: 0.564
# Epochs: 600	Training Binary CE Loss: 0.5625	Validation Binary CE Loss: 1.47	Training Accuracy: 0.668	Validation Accuracy: 0.572
# Epochs: 700	Training Binary CE Loss: 0.5225	Validation Binary CE Loss: 2.4431	Training Accuracy: 0.712	Validation Accuracy: 0.58
# Epochs: 800	Training Binary CE Loss: 0.8749	Validation Binary CE Loss: 2.2009	Training Accuracy: 0.708	Validation Accuracy: 0.564
# Epochs: 900	Training Binary CE Loss: 0.8309	Validation Binary CE Loss: 2.6795	Training Accuracy: 0.68	Validation Accuracy: 0.564
# Epochs: 1000	Training Binary CE Loss: 0.8668	Validation Binary CE Loss: 4.3297	Training Accuracy: 0.752	Validation Accuracy: 0.544
# Epochs: 1100	Training Binary CE Loss: 0.8465	Validation Binary CE Loss: 4.4177	Training Accuracy: 0.744	Validation Accuracy: 0.532
# Epochs: 1200	Training Binary CE Loss: 0.8417	Validation Binary CE Loss: 4.406	Training Accuracy: 0.748	Validation Accuracy: 0.58
# acc_opt_cut:  0.509 	 pwr_opt_cut 0.001
# maximum power of acc_opt_cut:,  2.696032762527466 	 maximum power of pwr_opt_cut:  2.8918871879577637
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8122	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6563	Training Accuracy: 0.572
# Epochs: 200	Training Binary CE Loss: 0.6477	Training Accuracy: 0.608
# Epochs: 300	Training Binary CE Loss: 0.6384	Training Accuracy: 0.62
# Epochs: 400	Training Binary CE Loss: 0.6296	Training Accuracy: 0.62
# Epochs: 500	Training Binary CE Loss: 0.6163	Training Accuracy: 0.646
# Epochs: 600	Training Binary CE Loss: 0.5995	Training Accuracy: 0.654
# Epochs: 700	Training Binary CE Loss: 0.5485	Training Accuracy: 0.696
# Epochs: 800	Training Binary CE Loss: 0.5083	Training Accuracy: 0.712
# Epochs: 900	Training Binary CE Loss: 0.4817	Training Accuracy: 0.738
# Epochs: 1000	Training Binary CE Loss: 0.4856	Training Accuracy: 0.724
# Epochs: 1100	Training Binary CE Loss: 0.4494	Training Accuracy: 0.744
# Epochs: 1200	Training Binary CE Loss: 0.4338	Training Accuracy: 0.76
# Epochs: 1300	Training Binary CE Loss: 0.4146	Training Accuracy: 0.784
# Epochs: 1400	Training Binary CE Loss: 0.394	Training Accuracy: 0.786
# Epochs: 1500	Training Binary CE Loss: 0.3853	Training Accuracy: 0.794
# Epochs: 1600	Training Binary CE Loss: 0.3722	Training Accuracy: 0.798
# Epochs: 1700	Training Binary CE Loss: 0.3485	Training Accuracy: 0.808
# Epochs: 1800	Training Binary CE Loss: 0.3373	Training Accuracy: 0.822
# Epochs: 1900	Training Binary CE Loss: 0.4068	Training Accuracy: 0.794
# Epochs: 2000	Training Binary CE Loss: 0.3254	Training Accuracy: 0.83
# Epochs: 2100	Training Binary CE Loss: 0.3184	Training Accuracy: 0.822
# Epochs: 2200	Training Binary CE Loss: 0.3373	Training Accuracy: 0.818
# Epochs: 2300	Training Binary CE Loss: 0.336	Training Accuracy: 0.84
# Epochs: 2400	Training Binary CE Loss: 0.2987	Training Accuracy: 0.84
# Statistics of maximizing acc: 0.9260513782501221 	 tau0_a: 0.6080000400543213 	 tau1_a: 0.35200002789497375
# Statistics of default: 0.8324050307273865 	 tau0_d: 0.6080000400543213 	 tau1_d: 0.35600000619888306
# Statistics of maximizing pwr: 3.2040696144104004 	 tau0_p: 0.1080000028014183 	 tau1_p: 0.7880000472068787
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments7
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7598	Validation Binary CE Loss: 0.7608	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6423	Validation Binary CE Loss: 0.7017	Training Accuracy: 0.62	Validation Accuracy: 0.54
# Epochs: 200	Training Binary CE Loss: 0.589	Validation Binary CE Loss: 0.7063	Training Accuracy: 0.66	Validation Accuracy: 0.54
# Epochs: 300	Training Binary CE Loss: 0.5403	Validation Binary CE Loss: 0.8635	Training Accuracy: 0.696	Validation Accuracy: 0.536
# Epochs: 400	Training Binary CE Loss: 0.519	Validation Binary CE Loss: 0.8953	Training Accuracy: 0.708	Validation Accuracy: 0.524
# Epochs: 500	Training Binary CE Loss: 0.4904	Validation Binary CE Loss: 1.059	Training Accuracy: 0.716	Validation Accuracy: 0.508
# Epochs: 600	Training Binary CE Loss: 0.4782	Validation Binary CE Loss: 1.2454	Training Accuracy: 0.736	Validation Accuracy: 0.528
# Epochs: 700	Training Binary CE Loss: 0.4747	Validation Binary CE Loss: 1.5776	Training Accuracy: 0.728	Validation Accuracy: 0.512
# Epochs: 800	Training Binary CE Loss: 0.4045	Validation Binary CE Loss: 1.8512	Training Accuracy: 0.784	Validation Accuracy: 0.532
# Epochs: 900	Training Binary CE Loss: 0.3889	Validation Binary CE Loss: 1.9869	Training Accuracy: 0.816	Validation Accuracy: 0.576
# Epochs: 1000	Training Binary CE Loss: 0.3694	Validation Binary CE Loss: 2.9291	Training Accuracy: 0.836	Validation Accuracy: 0.568
# Epochs: 1100	Training Binary CE Loss: 0.3367	Validation Binary CE Loss: 2.2996	Training Accuracy: 0.848	Validation Accuracy: 0.54
# Epochs: 1200	Training Binary CE Loss: 0.3068	Validation Binary CE Loss: 3.2844	Training Accuracy: 0.852	Validation Accuracy: 0.556
# acc_opt_cut:  0.279 	 pwr_opt_cut 0.279
# maximum power of acc_opt_cut:,  2.9124107360839844 	 maximum power of pwr_opt_cut:  2.9124107360839844
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.811	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6607	Training Accuracy: 0.552
# Epochs: 200	Training Binary CE Loss: 0.6486	Training Accuracy: 0.592
# Epochs: 300	Training Binary CE Loss: 0.633	Training Accuracy: 0.6
# Epochs: 400	Training Binary CE Loss: 0.5964	Training Accuracy: 0.654
# Epochs: 500	Training Binary CE Loss: 0.5728	Training Accuracy: 0.688
# Epochs: 600	Training Binary CE Loss: 0.543	Training Accuracy: 0.71
# Epochs: 700	Training Binary CE Loss: 0.5255	Training Accuracy: 0.718
# Epochs: 800	Training Binary CE Loss: 0.4816	Training Accuracy: 0.738
# Epochs: 900	Training Binary CE Loss: 0.4585	Training Accuracy: 0.758
# Epochs: 1000	Training Binary CE Loss: 0.4357	Training Accuracy: 0.774
# Epochs: 1100	Training Binary CE Loss: 0.4116	Training Accuracy: 0.782
# Epochs: 1200	Training Binary CE Loss: 0.3727	Training Accuracy: 0.804
# Epochs: 1300	Training Binary CE Loss: 0.3653	Training Accuracy: 0.812
# Epochs: 1400	Training Binary CE Loss: 0.37	Training Accuracy: 0.804
# Epochs: 1500	Training Binary CE Loss: 0.3476	Training Accuracy: 0.818
# Epochs: 1600	Training Binary CE Loss: 0.3141	Training Accuracy: 0.838
# Epochs: 1700	Training Binary CE Loss: 0.3734	Training Accuracy: 0.818
# Epochs: 1800	Training Binary CE Loss: 0.3273	Training Accuracy: 0.838
# Epochs: 1900	Training Binary CE Loss: 0.2885	Training Accuracy: 0.852
# Epochs: 2000	Training Binary CE Loss: 0.2762	Training Accuracy: 0.864
# Epochs: 2100	Training Binary CE Loss: 0.2928	Training Accuracy: 0.864
# Epochs: 2200	Training Binary CE Loss: 0.2842	Training Accuracy: 0.874
# Epochs: 2300	Training Binary CE Loss: 0.2713	Training Accuracy: 0.862
# Epochs: 2400	Training Binary CE Loss: 0.2595	Training Accuracy: 0.87
# Statistics of maximizing acc: 1.4940346479415894 	 tau0_a: 0.328000009059906 	 tau1_a: 0.6080000400543213
# Statistics of default: 0.8069612979888916 	 tau0_d: 0.4520000219345093 	 tau1_d: 0.5120000243186951
# Statistics of maximizing pwr: 1.4940346479415894 	 tau0_p: 0.328000009059906 	 tau1_p: 0.6080000400543213
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments8
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7631	Validation Binary CE Loss: 0.7558	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6388	Validation Binary CE Loss: 0.6736	Training Accuracy: 0.584	Validation Accuracy: 0.552
# Epochs: 200	Training Binary CE Loss: 0.619	Validation Binary CE Loss: 0.7208	Training Accuracy: 0.592	Validation Accuracy: 0.54
# Epochs: 300	Training Binary CE Loss: 0.5994	Validation Binary CE Loss: 0.7455	Training Accuracy: 0.648	Validation Accuracy: 0.528
# Epochs: 400	Training Binary CE Loss: 0.5634	Validation Binary CE Loss: 1.0116	Training Accuracy: 0.668	Validation Accuracy: 0.544
# Epochs: 500	Training Binary CE Loss: 0.5505	Validation Binary CE Loss: 1.9311	Training Accuracy: 0.668	Validation Accuracy: 0.508
# Epochs: 600	Training Binary CE Loss: 0.519	Validation Binary CE Loss: 2.911	Training Accuracy: 0.68	Validation Accuracy: 0.536
# Epochs: 700	Training Binary CE Loss: 0.5122	Validation Binary CE Loss: 2.1174	Training Accuracy: 0.732	Validation Accuracy: 0.524
# Epochs: 800	Training Binary CE Loss: 0.502	Validation Binary CE Loss: 2.3979	Training Accuracy: 0.716	Validation Accuracy: 0.54
# Epochs: 900	Training Binary CE Loss: 0.479	Validation Binary CE Loss: 3.8027	Training Accuracy: 0.744	Validation Accuracy: 0.536
# Epochs: 1000	Training Binary CE Loss: 0.4631	Validation Binary CE Loss: 3.2711	Training Accuracy: 0.744	Validation Accuracy: 0.54
# Epochs: 1100	Training Binary CE Loss: 0.4508	Validation Binary CE Loss: 3.5798	Training Accuracy: 0.764	Validation Accuracy: 0.532
# Epochs: 1200	Training Binary CE Loss: 0.4265	Validation Binary CE Loss: 4.5902	Training Accuracy: 0.768	Validation Accuracy: 0.548
# acc_opt_cut:  0.134 	 pwr_opt_cut 0.134
# maximum power of acc_opt_cut:,  3.0913703441619873 	 maximum power of pwr_opt_cut:  3.0913703441619873
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8088	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6405	Training Accuracy: 0.594
# Epochs: 200	Training Binary CE Loss: 0.6259	Training Accuracy: 0.626
# Epochs: 300	Training Binary CE Loss: 0.5939	Training Accuracy: 0.66
# Epochs: 400	Training Binary CE Loss: 0.5757	Training Accuracy: 0.66
# Epochs: 500	Training Binary CE Loss: 0.5599	Training Accuracy: 0.676
# Epochs: 600	Training Binary CE Loss: 0.5209	Training Accuracy: 0.682
# Epochs: 700	Training Binary CE Loss: 0.4918	Training Accuracy: 0.706
# Epochs: 800	Training Binary CE Loss: 0.4544	Training Accuracy: 0.748
# Epochs: 900	Training Binary CE Loss: 0.4416	Training Accuracy: 0.756
# Epochs: 1000	Training Binary CE Loss: 0.4427	Training Accuracy: 0.756
# Epochs: 1100	Training Binary CE Loss: 0.4554	Training Accuracy: 0.74
# Epochs: 1200	Training Binary CE Loss: 0.4543	Training Accuracy: 0.764
# Epochs: 1300	Training Binary CE Loss: 0.364	Training Accuracy: 0.822
# Epochs: 1400	Training Binary CE Loss: 0.335	Training Accuracy: 0.846
# Epochs: 1500	Training Binary CE Loss: 0.3238	Training Accuracy: 0.846
# Epochs: 1600	Training Binary CE Loss: 0.3081	Training Accuracy: 0.848
# Epochs: 1700	Training Binary CE Loss: 0.3148	Training Accuracy: 0.836
# Epochs: 1800	Training Binary CE Loss: 0.2999	Training Accuracy: 0.856
# Epochs: 1900	Training Binary CE Loss: 0.4663	Training Accuracy: 0.852
# Epochs: 2000	Training Binary CE Loss: 0.5116	Training Accuracy: 0.84
# Epochs: 2100	Training Binary CE Loss: 0.4821	Training Accuracy: 0.848
# Epochs: 2200	Training Binary CE Loss: 0.305	Training Accuracy: 0.842
# Epochs: 2300	Training Binary CE Loss: 0.3658	Training Accuracy: 0.814
# Epochs: 2400	Training Binary CE Loss: 0.4775	Training Accuracy: 0.858
# Statistics of maximizing acc: 3.837132215499878 	 tau0_a: 0.18400001525878906 	 tau1_a: 0.6680000424385071
# Statistics of default: 1.1654613018035889 	 tau0_d: 0.4520000219345093 	 tau1_d: 0.4960000216960907
# Statistics of maximizing pwr: 3.837132215499878 	 tau0_p: 0.18400001525878906 	 tau1_p: 0.6680000424385071
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments9
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7484	Validation Binary CE Loss: 0.7478	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6305	Validation Binary CE Loss: 0.6739	Training Accuracy: 0.588	Validation Accuracy: 0.524
# Epochs: 200	Training Binary CE Loss: 0.6017	Validation Binary CE Loss: 0.6846	Training Accuracy: 0.604	Validation Accuracy: 0.548
# Epochs: 300	Training Binary CE Loss: 0.5831	Validation Binary CE Loss: 0.8174	Training Accuracy: 0.62	Validation Accuracy: 0.524
# Epochs: 400	Training Binary CE Loss: 0.5733	Validation Binary CE Loss: 0.8066	Training Accuracy: 0.612	Validation Accuracy: 0.552
# Epochs: 500	Training Binary CE Loss: 0.5746	Validation Binary CE Loss: 0.9588	Training Accuracy: 0.624	Validation Accuracy: 0.556
# Epochs: 600	Training Binary CE Loss: 0.5451	Validation Binary CE Loss: 1.3043	Training Accuracy: 0.644	Validation Accuracy: 0.56
# Epochs: 700	Training Binary CE Loss: 0.5692	Validation Binary CE Loss: 0.9175	Training Accuracy: 0.608	Validation Accuracy: 0.548
# Epochs: 800	Training Binary CE Loss: 0.5439	Validation Binary CE Loss: 1.3585	Training Accuracy: 0.644	Validation Accuracy: 0.54
# Epochs: 900	Training Binary CE Loss: 0.6218	Validation Binary CE Loss: 1.0216	Training Accuracy: 0.596	Validation Accuracy: 0.52
# Epochs: 1000	Training Binary CE Loss: 0.5958	Validation Binary CE Loss: 1.0487	Training Accuracy: 0.616	Validation Accuracy: 0.52
# Epochs: 1100	Training Binary CE Loss: 0.5739	Validation Binary CE Loss: 1.4172	Training Accuracy: 0.6	Validation Accuracy: 0.504
# Epochs: 1200	Training Binary CE Loss: 0.5624	Validation Binary CE Loss: 2.0221	Training Accuracy: 0.62	Validation Accuracy: 0.508
# acc_opt_cut:  0.008 	 pwr_opt_cut 0.008
# maximum power of acc_opt_cut:,  2.0100340843200684 	 maximum power of pwr_opt_cut:  2.0100340843200684
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.811	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6362	Training Accuracy: 0.6
# Epochs: 200	Training Binary CE Loss: 0.6279	Training Accuracy: 0.618
# Epochs: 300	Training Binary CE Loss: 0.6191	Training Accuracy: 0.624
# Epochs: 400	Training Binary CE Loss: 0.5999	Training Accuracy: 0.624
# Epochs: 500	Training Binary CE Loss: 0.581	Training Accuracy: 0.646
# Epochs: 600	Training Binary CE Loss: 0.5305	Training Accuracy: 0.686
# Epochs: 700	Training Binary CE Loss: 0.4863	Training Accuracy: 0.724
# Epochs: 800	Training Binary CE Loss: 0.4542	Training Accuracy: 0.75
# Epochs: 900	Training Binary CE Loss: 0.4132	Training Accuracy: 0.78
# Epochs: 1000	Training Binary CE Loss: 0.5841	Training Accuracy: 0.786
# Epochs: 1100	Training Binary CE Loss: 0.6265	Training Accuracy: 0.778
# Epochs: 1200	Training Binary CE Loss: 0.5517	Training Accuracy: 0.804
# Epochs: 1300	Training Binary CE Loss: 0.5544	Training Accuracy: 0.798
# Epochs: 1400	Training Binary CE Loss: 0.5233	Training Accuracy: 0.826
# Epochs: 1500	Training Binary CE Loss: 0.6047	Training Accuracy: 0.804
# Epochs: 1600	Training Binary CE Loss: 0.6506	Training Accuracy: 0.826
# Epochs: 1700	Training Binary CE Loss: 0.5043	Training Accuracy: 0.826
# Epochs: 1800	Training Binary CE Loss: 0.3119	Training Accuracy: 0.838
# Epochs: 1900	Training Binary CE Loss: 0.3272	Training Accuracy: 0.812
# Epochs: 2000	Training Binary CE Loss: 0.2695	Training Accuracy: 0.862
# Epochs: 2100	Training Binary CE Loss: 0.2817	Training Accuracy: 0.862
# Epochs: 2200	Training Binary CE Loss: 0.2647	Training Accuracy: 0.864
# Epochs: 2300	Training Binary CE Loss: 0.2596	Training Accuracy: 0.868
# Epochs: 2400	Training Binary CE Loss: 0.252	Training Accuracy: 0.864
# Statistics of maximizing acc: 1.4375791549682617 	 tau0_a: 0.22800001502037048 	 tau1_a: 0.7160000205039978
# Statistics of default: 0.26912516355514526 	 tau0_d: 0.45600003004074097 	 tau1_d: 0.5320000052452087
# Statistics of maximizing pwr: 1.4375791549682617 	 tau0_p: 0.22800001502037048 	 tau1_p: 0.7160000205039978
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments10
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7653	Validation Binary CE Loss: 0.7668	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6547	Validation Binary CE Loss: 0.6473	Training Accuracy: 0.596	Validation Accuracy: 0.608
# Epochs: 200	Training Binary CE Loss: 0.6315	Validation Binary CE Loss: 0.6615	Training Accuracy: 0.6	Validation Accuracy: 0.616
# Epochs: 300	Training Binary CE Loss: 0.5988	Validation Binary CE Loss: 0.7664	Training Accuracy: 0.616	Validation Accuracy: 0.54
# Epochs: 400	Training Binary CE Loss: 0.5687	Validation Binary CE Loss: 0.9554	Training Accuracy: 0.66	Validation Accuracy: 0.54
# Epochs: 500	Training Binary CE Loss: 0.517	Validation Binary CE Loss: 1.1049	Training Accuracy: 0.684	Validation Accuracy: 0.524
# Epochs: 600	Training Binary CE Loss: 0.4617	Validation Binary CE Loss: 1.5429	Training Accuracy: 0.72	Validation Accuracy: 0.508
# Epochs: 700	Training Binary CE Loss: 0.4355	Validation Binary CE Loss: 1.5383	Training Accuracy: 0.76	Validation Accuracy: 0.516
# Epochs: 800	Training Binary CE Loss: 0.3966	Validation Binary CE Loss: 2.024	Training Accuracy: 0.752	Validation Accuracy: 0.504
# Epochs: 900	Training Binary CE Loss: 0.3798	Validation Binary CE Loss: 3.4379	Training Accuracy: 0.768	Validation Accuracy: 0.472
# Epochs: 1000	Training Binary CE Loss: 0.3978	Validation Binary CE Loss: 3.1151	Training Accuracy: 0.768	Validation Accuracy: 0.512
# Epochs: 1100	Training Binary CE Loss: 0.3751	Validation Binary CE Loss: 3.2317	Training Accuracy: 0.78	Validation Accuracy: 0.528
# Epochs: 1200	Training Binary CE Loss: 0.3666	Validation Binary CE Loss: 4.4785	Training Accuracy: 0.8	Validation Accuracy: 0.48
# acc_opt_cut:  0.038 	 pwr_opt_cut 0.005
# maximum power of acc_opt_cut:,  3.1669726371765137 	 maximum power of pwr_opt_cut:  3.4359211921691895
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8149	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6432	Training Accuracy: 0.602
# Epochs: 200	Training Binary CE Loss: 0.6282	Training Accuracy: 0.618
# Epochs: 300	Training Binary CE Loss: 0.6006	Training Accuracy: 0.644
# Epochs: 400	Training Binary CE Loss: 0.5726	Training Accuracy: 0.66
# Epochs: 500	Training Binary CE Loss: 0.5676	Training Accuracy: 0.658
# Epochs: 600	Training Binary CE Loss: 0.5203	Training Accuracy: 0.7
# Epochs: 700	Training Binary CE Loss: 0.5	Training Accuracy: 0.702
# Epochs: 800	Training Binary CE Loss: 0.4583	Training Accuracy: 0.742
# Epochs: 900	Training Binary CE Loss: 0.4702	Training Accuracy: 0.732
# Epochs: 1000	Training Binary CE Loss: 0.4001	Training Accuracy: 0.778
# Epochs: 1100	Training Binary CE Loss: 0.4076	Training Accuracy: 0.78
# Epochs: 1200	Training Binary CE Loss: 0.3622	Training Accuracy: 0.814
# Epochs: 1300	Training Binary CE Loss: 0.3659	Training Accuracy: 0.808
# Epochs: 1400	Training Binary CE Loss: 0.3625	Training Accuracy: 0.816
# Epochs: 1500	Training Binary CE Loss: 0.3367	Training Accuracy: 0.832
# Epochs: 1600	Training Binary CE Loss: 0.3177	Training Accuracy: 0.834
# Epochs: 1700	Training Binary CE Loss: 0.3571	Training Accuracy: 0.822
# Epochs: 1800	Training Binary CE Loss: 0.3333	Training Accuracy: 0.832
# Epochs: 1900	Training Binary CE Loss: 0.3344	Training Accuracy: 0.826
# Epochs: 2000	Training Binary CE Loss: 0.338	Training Accuracy: 0.828
# Epochs: 2100	Training Binary CE Loss: 0.336	Training Accuracy: 0.82
# Epochs: 2200	Training Binary CE Loss: 0.3176	Training Accuracy: 0.838
# Epochs: 2300	Training Binary CE Loss: 0.6991	Training Accuracy: 0.828
# Epochs: 2400	Training Binary CE Loss: 0.6749	Training Accuracy: 0.832
# Statistics of maximizing acc: 2.7590956687927246 	 tau0_a: 0.18400001525878906 	 tau1_a: 0.7120000123977661
# Statistics of default: 1.461323857307434 	 tau0_d: 0.5640000104904175 	 tau1_d: 0.3720000088214874
# Statistics of maximizing pwr: 3.9295570850372314 	 tau0_p: 0.13600000739097595 	 tau1_p: 0.7240000367164612
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments11
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.739	Validation Binary CE Loss: 0.7429	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6279	Validation Binary CE Loss: 0.6391	Training Accuracy: 0.608	Validation Accuracy: 0.592
# Epochs: 200	Training Binary CE Loss: 0.5895	Validation Binary CE Loss: 0.6917	Training Accuracy: 0.64	Validation Accuracy: 0.6
# Epochs: 300	Training Binary CE Loss: 0.5541	Validation Binary CE Loss: 1.0098	Training Accuracy: 0.672	Validation Accuracy: 0.58
# Epochs: 400	Training Binary CE Loss: 0.5333	Validation Binary CE Loss: 1.1709	Training Accuracy: 0.644	Validation Accuracy: 0.544
# Epochs: 500	Training Binary CE Loss: 0.5108	Validation Binary CE Loss: 1.7335	Training Accuracy: 0.68	Validation Accuracy: 0.52
# Epochs: 600	Training Binary CE Loss: 0.4934	Validation Binary CE Loss: 1.9465	Training Accuracy: 0.692	Validation Accuracy: 0.524
# Epochs: 700	Training Binary CE Loss: 0.4772	Validation Binary CE Loss: 2.6892	Training Accuracy: 0.728	Validation Accuracy: 0.564
# Epochs: 800	Training Binary CE Loss: 0.4606	Validation Binary CE Loss: 3.5009	Training Accuracy: 0.728	Validation Accuracy: 0.576
# Epochs: 900	Training Binary CE Loss: 0.4342	Validation Binary CE Loss: 3.8153	Training Accuracy: 0.756	Validation Accuracy: 0.588
# Epochs: 1000	Training Binary CE Loss: 0.7549	Validation Binary CE Loss: 3.5225	Training Accuracy: 0.732	Validation Accuracy: 0.584
# Epochs: 1100	Training Binary CE Loss: 0.8131	Validation Binary CE Loss: 5.0056	Training Accuracy: 0.724	Validation Accuracy: 0.54
# Epochs: 1200	Training Binary CE Loss: 0.4934	Validation Binary CE Loss: 1.995	Training Accuracy: 0.728	Validation Accuracy: 0.588
# acc_opt_cut:  0.454 	 pwr_opt_cut 0.17200000000000001
# maximum power of acc_opt_cut:,  3.3917551040649414 	 maximum power of pwr_opt_cut:  3.643082618713379
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8106	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6013	Training Accuracy: 0.616
# Epochs: 200	Training Binary CE Loss: 0.593	Training Accuracy: 0.638
# ...
# Epochs: 2300	Training Binary CE Loss: 0.4914	Training Accuracy: 0.858
# Epochs: 2400	Training Binary CE Loss: 0.4724	Training Accuracy: 0.856
# Statistics of maximizing acc: 2.6026065349578857 	 tau0_a: 0.320000022649765 	 tau1_a: 0.5680000185966492
# Statistics of default: 2.1610565185546875 	 tau0_d: 0.42000001668930054 	 tau1_d: 0.484000027179718
# Statistics of maximizing pwr: 2.5136685371398926 	 tau0_p: 0.14800000190734863 	 tau1_p: 0.7640000581741333
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments43
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7457	Validation Binary CE Loss: 0.7412	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6279	Validation Binary CE Loss: 0.629	Training Accuracy: 0.608	Validation Accuracy: 0.612
# Epochs: 200	Training Binary CE Loss: 0.624	Validation Binary CE Loss: 0.631	Training Accuracy: 0.608	Validation Accuracy: 0.608
# Epochs: 300	Training Binary CE Loss: 0.6137	Validation Binary CE Loss: 0.6256	Training Accuracy: 0.624	Validation Accuracy: 0.64
# Epochs: 400	Training Binary CE Loss: 0.5939	Validation Binary CE Loss: 0.6611	Training Accuracy: 0.656	Validation Accuracy: 0.608
# Epochs: 500	Training Binary CE Loss: 0.5758	Validation Binary CE Loss: 0.6826	Training Accuracy: 0.688	Validation Accuracy: 0.56
# Epochs: 600	Training Binary CE Loss: 0.5849	Validation Binary CE Loss: 0.6353	Training Accuracy: 0.66	Validation Accuracy: 0.604
# Epochs: 700	Training Binary CE Loss: 0.5539	Validation Binary CE Loss: 0.7067	Training Accuracy: 0.704	Validation Accuracy: 0.584
# Epochs: 800	Training Binary CE Loss: 0.5118	Validation Binary CE Loss: 0.8587	Training Accuracy: 0.7	Validation Accuracy: 0.608
# Epochs: 900	Training Binary CE Loss: 0.4957	Validation Binary CE Loss: 0.8749	Training Accuracy: 0.732	Validation Accuracy: 0.596
# Epochs: 1000	Training Binary CE Loss: 0.4612	Validation Binary CE Loss: 1.2262	Training Accuracy: 0.764	Validation Accuracy: 0.616
# Epochs: 1100	Training Binary CE Loss: 0.5142	Validation Binary CE Loss: 1.6921	Training Accuracy: 0.748	Validation Accuracy: 0.568
# Epochs: 1200	Training Binary CE Loss: 1.0931	Validation Binary CE Loss: 1.5265	Training Accuracy: 0.756	Validation Accuracy: 0.576
# acc_opt_cut:  0.328 	 pwr_opt_cut 0.003
# maximum power of acc_opt_cut:,  4.171905517578125 	 maximum power of pwr_opt_cut:  5.052910804748535
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8117	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6344	Training Accuracy: 0.6
# Epochs: 200	Training Binary CE Loss: 0.6151	Training Accuracy: 0.612
# Epochs: 300	Training Binary CE Loss: 0.6016	Training Accuracy: 0.636
# Epochs: 400	Training Binary CE Loss: 0.5906	Training Accuracy: 0.65
# Epochs: 500	Training Binary CE Loss: 0.5632	Training Accuracy: 0.666
# Epochs: 600	Training Binary CE Loss: 0.5439	Training Accuracy: 0.672
# Epochs: 700	Training Binary CE Loss: 0.5304	Training Accuracy: 0.678
# Epochs: 800	Training Binary CE Loss: 0.4999	Training Accuracy: 0.696
# Epochs: 900	Training Binary CE Loss: 0.5301	Training Accuracy: 0.656
# Epochs: 1000	Training Binary CE Loss: 0.4903	Training Accuracy: 0.694
# Epochs: 1100	Training Binary CE Loss: 0.4667	Training Accuracy: 0.706
# Epochs: 1200	Training Binary CE Loss: 0.4507	Training Accuracy: 0.706
# Epochs: 1300	Training Binary CE Loss: 0.4538	Training Accuracy: 0.732
# Epochs: 1400	Training Binary CE Loss: 0.4444	Training Accuracy: 0.72
# Epochs: 1500	Training Binary CE Loss: 0.4396	Training Accuracy: 0.73
# Epochs: 1600	Training Binary CE Loss: 0.4855	Training Accuracy: 0.7
# Epochs: 1700	Training Binary CE Loss: 0.4554	Training Accuracy: 0.718
# Epochs: 1800	Training Binary CE Loss: 0.4226	Training Accuracy: 0.746
# Epochs: 1900	Training Binary CE Loss: 0.4047	Training Accuracy: 0.75
# Epochs: 2000	Training Binary CE Loss: 0.4603	Training Accuracy: 0.72
# Epochs: 2100	Training Binary CE Loss: 0.4407	Training Accuracy: 0.724
# Epochs: 2200	Training Binary CE Loss: 0.4329	Training Accuracy: 0.73
# Epochs: 2300	Training Binary CE Loss: 0.421	Training Accuracy: 0.726
# Epochs: 2400	Training Binary CE Loss: 0.4072	Training Accuracy: 0.738
# Statistics of maximizing acc: 3.5876777172088623 	 tau0_a: 0.19600000977516174 	 tau1_a: 0.6640000343322754
# Statistics of default: 3.220155715942383 	 tau0_d: 0.2160000056028366 	 tau1_d: 0.656000018119812
# Statistics of maximizing pwr: 3.726492166519165 	 tau0_p: 0.13600000739097595 	 tau1_p: 0.7320000529289246
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments44
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.758	Validation Binary CE Loss: 0.7567	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6537	Validation Binary CE Loss: 0.6976	Training Accuracy: 0.548	Validation Accuracy: 0.528
# Epochs: 200	Training Binary CE Loss: 0.6303	Validation Binary CE Loss: 0.732	Training Accuracy: 0.608	Validation Accuracy: 0.556
# Epochs: 300	Training Binary CE Loss: 0.6154	Validation Binary CE Loss: 1.0899	Training Accuracy: 0.604	Validation Accuracy: 0.512
# Epochs: 400	Training Binary CE Loss: 0.5902	Validation Binary CE Loss: 1.7105	Training Accuracy: 0.66	Validation Accuracy: 0.528
# Epochs: 500	Training Binary CE Loss: 0.5635	Validation Binary CE Loss: 2.1754	Training Accuracy: 0.668	Validation Accuracy: 0.532
# Epochs: 600	Training Binary CE Loss: 0.5543	Validation Binary CE Loss: 2.1504	Training Accuracy: 0.692	Validation Accuracy: 0.54
# Epochs: 700	Training Binary CE Loss: 0.5244	Validation Binary CE Loss: 2.2919	Training Accuracy: 0.696	Validation Accuracy: 0.52
# Epochs: 800	Training Binary CE Loss: 0.5153	Validation Binary CE Loss: 2.4755	Training Accuracy: 0.704	Validation Accuracy: 0.508
# Epochs: 900	Training Binary CE Loss: 0.4848	Validation Binary CE Loss: 2.6696	Training Accuracy: 0.7	Validation Accuracy: 0.496
# Epochs: 1000	Training Binary CE Loss: 0.5466	Validation Binary CE Loss: 2.6352	Training Accuracy: 0.692	Validation Accuracy: 0.496
# Epochs: 1100	Training Binary CE Loss: 0.462	Validation Binary CE Loss: 3.4009	Training Accuracy: 0.756	Validation Accuracy: 0.512
# Epochs: 1200	Training Binary CE Loss: 0.4101	Validation Binary CE Loss: 4.1989	Training Accuracy: 0.78	Validation Accuracy: 0.528
# acc_opt_cut:  0.008 	 pwr_opt_cut 0.008
# maximum power of acc_opt_cut:,  3.1598713397979736 	 maximum power of pwr_opt_cut:  3.1598713397979736
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8102	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6332	Training Accuracy: 0.626
# Epochs: 200	Training Binary CE Loss: 0.6264	Training Accuracy: 0.632
# Epochs: 300	Training Binary CE Loss: 0.6145	Training Accuracy: 0.622
# Epochs: 400	Training Binary CE Loss: 0.5996	Training Accuracy: 0.662
# Epochs: 500	Training Binary CE Loss: 0.5881	Training Accuracy: 0.666
# Epochs: 600	Training Binary CE Loss: 0.5491	Training Accuracy: 0.682
# Epochs: 700	Training Binary CE Loss: 0.5015	Training Accuracy: 0.726
# Epochs: 800	Training Binary CE Loss: 0.4552	Training Accuracy: 0.762
# Epochs: 900	Training Binary CE Loss: 0.4368	Training Accuracy: 0.764
# Epochs: 1000	Training Binary CE Loss: 0.4091	Training Accuracy: 0.762
# Epochs: 1100	Training Binary CE Loss: 0.3771	Training Accuracy: 0.792
# Epochs: 1200	Training Binary CE Loss: 0.3422	Training Accuracy: 0.814
# Epochs: 1300	Training Binary CE Loss: 0.504	Training Accuracy: 0.83
# Epochs: 1400	Training Binary CE Loss: 0.5092	Training Accuracy: 0.81
# Epochs: 1500	Training Binary CE Loss: 0.3548	Training Accuracy: 0.818
# Epochs: 1600	Training Binary CE Loss: 0.3415	Training Accuracy: 0.816
# Epochs: 1700	Training Binary CE Loss: 0.3287	Training Accuracy: 0.838
# Epochs: 1800	Training Binary CE Loss: 0.3161	Training Accuracy: 0.844
# Epochs: 1900	Training Binary CE Loss: 0.4904	Training Accuracy: 0.848
# Epochs: 2000	Training Binary CE Loss: 1.0672	Training Accuracy: 0.862
# Epochs: 2100	Training Binary CE Loss: 0.8365	Training Accuracy: 0.868
# Epochs: 2200	Training Binary CE Loss: 0.8305	Training Accuracy: 0.856
# Epochs: 2300	Training Binary CE Loss: 0.8681	Training Accuracy: 0.862
# Epochs: 2400	Training Binary CE Loss: 0.848	Training Accuracy: 0.882
# Statistics of maximizing acc: 3.672809362411499 	 tau0_a: 0.1600000113248825 	 tau1_a: 0.7040000557899475
# Statistics of default: 1.8849726915359497 	 tau0_d: 0.46000000834465027 	 tau1_d: 0.45600003004074097
# Statistics of maximizing pwr: 3.672809362411499 	 tau0_p: 0.1600000113248825 	 tau1_p: 0.7040000557899475
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments45
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.7569	Validation Binary CE Loss: 0.7622	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6283	Validation Binary CE Loss: 0.676	Training Accuracy: 0.64	Validation Accuracy: 0.572
# Epochs: 200	Training Binary CE Loss: 0.5715	Validation Binary CE Loss: 0.7519	Training Accuracy: 0.668	Validation Accuracy: 0.592
# Epochs: 300	Training Binary CE Loss: 0.5444	Validation Binary CE Loss: 1.0838	Training Accuracy: 0.7	Validation Accuracy: 0.576
# Epochs: 400	Training Binary CE Loss: 0.534	Validation Binary CE Loss: 1.1366	Training Accuracy: 0.708	Validation Accuracy: 0.548
# Epochs: 500	Training Binary CE Loss: 0.4931	Validation Binary CE Loss: 1.2487	Training Accuracy: 0.744	Validation Accuracy: 0.524
# Epochs: 600	Training Binary CE Loss: 0.4836	Validation Binary CE Loss: 1.322	Training Accuracy: 0.752	Validation Accuracy: 0.548
# Epochs: 700	Training Binary CE Loss: 0.4692	Validation Binary CE Loss: 2.0505	Training Accuracy: 0.76	Validation Accuracy: 0.496
# Epochs: 800	Training Binary CE Loss: 0.3835	Validation Binary CE Loss: 2.445	Training Accuracy: 0.804	Validation Accuracy: 0.52
# Epochs: 900	Training Binary CE Loss: 0.3757	Validation Binary CE Loss: 2.862	Training Accuracy: 0.796	Validation Accuracy: 0.528
# Epochs: 1000	Training Binary CE Loss: 0.3415	Validation Binary CE Loss: 3.9493	Training Accuracy: 0.812	Validation Accuracy: 0.524
# Epochs: 1100	Training Binary CE Loss: 0.3356	Validation Binary CE Loss: 3.5025	Training Accuracy: 0.836	Validation Accuracy: 0.5
# Epochs: 1200	Training Binary CE Loss: 0.2996	Validation Binary CE Loss: 4.9228	Training Accuracy: 0.848	Validation Accuracy: 0.548
# acc_opt_cut:  0.132 	 pwr_opt_cut 0.132
# maximum power of acc_opt_cut:,  4.111958026885986 	 maximum power of pwr_opt_cut:  4.111958026885986
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# 				   Testing
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epochs: 0	Training Binary CE Loss: 0.8119	Training Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6491	Training Accuracy: 0.588
# Epochs: 200	Training Binary CE Loss: 0.6328	Training Accuracy: 0.612
# Epochs: 300	Training Binary CE Loss: 0.6273	Training Accuracy: 0.604
# Epochs: 400	Training Binary CE Loss: 0.6026	Training Accuracy: 0.648
# Epochs: 500	Training Binary CE Loss: 0.5957	Training Accuracy: 0.636
# Epochs: 600	Training Binary CE Loss: 0.5575	Training Accuracy: 0.67
# Epochs: 700	Training Binary CE Loss: 0.5313	Training Accuracy: 0.678
# Epochs: 800	Training Binary CE Loss: 0.4992	Training Accuracy: 0.72
# Epochs: 900	Training Binary CE Loss: 0.5009	Training Accuracy: 0.722
# Epochs: 1000	Training Binary CE Loss: 0.4581	Training Accuracy: 0.762
# Epochs: 1100	Training Binary CE Loss: 0.4435	Training Accuracy: 0.772
# Epochs: 1200	Training Binary CE Loss: 0.3958	Training Accuracy: 0.788
# Epochs: 1300	Training Binary CE Loss: 0.3812	Training Accuracy: 0.81
# Epochs: 1400	Training Binary CE Loss: 0.3783	Training Accuracy: 0.796
# Epochs: 1500	Training Binary CE Loss: 0.3749	Training Accuracy: 0.812
# Epochs: 1600	Training Binary CE Loss: 0.3784	Training Accuracy: 0.796
# Epochs: 1700	Training Binary CE Loss: 0.3422	Training Accuracy: 0.838
# Epochs: 1800	Training Binary CE Loss: 0.366	Training Accuracy: 0.802
# Epochs: 1900	Training Binary CE Loss: 0.321	Training Accuracy: 0.842
# Epochs: 2000	Training Binary CE Loss: 0.6589	Training Accuracy: 0.792
# Epochs: 2100	Training Binary CE Loss: 0.6474	Training Accuracy: 0.848
# Epochs: 2200	Training Binary CE Loss: 0.3537	Training Accuracy: 0.812
# Epochs: 2300	Training Binary CE Loss: 0.2938	Training Accuracy: 0.86
# Epochs: 2400	Training Binary CE Loss: 0.2949	Training Accuracy: 0.842
# Statistics of maximizing acc: 1.273162603378296 	 tau0_a: 0.2720000147819519 	 tau1_a: 0.6760000586509705
# Statistics of default: 0.17903347313404083 	 tau0_d: 0.5160000324249268 	 tau1_d: 0.47600001096725464
# Statistics of maximizing pwr: 1.273162603378296 	 tau0_p: 0.2720000147819519 	 tau1_p: 0.6760000586509705
# ====================================================================================================
# 				Imbalance Ratio: 1
# 				Experiments46
# ====================================================================================================
# Epochs: 0	Training Binary CE Loss: 0.754	Validation Binary CE Loss: 0.7524	Training Accuracy: 0.5	Validation Accuracy: 0.5
# Epochs: 100	Training Binary CE Loss: 0.6312	Validation Binary CE Loss: 0.7074	Training Accuracy: 0.616	Validation Accuracy: 0.516
# Epochs: 200	Training Binary CE Loss: 0.6214	Validation Binary CE Loss: 0.6744	Training Accuracy: 0.612	Validation Accuracy: 0.556
# Epochs: 300	Training Binary CE Loss: 0.5908	Validation Binary CE Loss: 0.7803	Training Accuracy: 0.66	Validation Accuracy: 0.516
# Epochs: 400	Training Binary CE Loss: 0.5335	Validation Binary CE Loss: 0.967	Training Accuracy: 0.7	Validation Accuracy: 0.592
# Epochs: 500	Training Binary CE Loss: 0.5223	Validation Binary CE Loss: 0.9914	Training Accuracy: 0.676	Validation Accuracy: 0.564
# Epochs: 600	Training Binary CE Loss: 0.4844	Validation Binary CE Loss: 1.07	Training Accuracy: 0.74	Validation Accuracy: 0.572
# Epochs: 700	Training Binary CE Loss: 0.4436	Validation Binary CE Loss: 2.2761	Training Accuracy: 0.768	Validation Accuracy: 0.576
# Epochs: 800	Training Binary CE Loss: 0.4183	Validation Binary CE Loss: 2.3625	Training Accuracy: 0.772	Validation Accuracy: 0.58
# Epochs: 900	Training Binary CE Loss: 0.3967	Validation Binary CE Loss: 3.9438	Training Accuracy: 0.8	Validation Accuracy: 0.62
# Epochs: 1000	Training Binary CE Loss: 0.3655	Validation Binary CE Loss: 3.7053	Training Accuracy: 0.824	Validation Accuracy: 0.588
# Epochs: 1100	Training Binary CE Loss: 0.3493	Validation Binary CE Loss: 3.7224	Training Accuracy: 0.816	Validation Accuracy: 0.604
# Epochs: 1200	Training Binary CE Loss: 0.3923	Validation Binary CE Loss: 4.5992	Training Accuracy: 0.852	Validation Accuracy: 0.584

# %%
# For each n in n_list, train deep kernel and run two-sample test
stats_a_dict = {}
stats_d_dict = {}
stats_p_dict = {}

acc_opt_cuts = []
pwr_opt_cuts = []

a_powers = {}
d_powers = {}
p_powers = {}

for r in ir_list:
    np.random.seed(1203)
    N1 = n1 * r
    N2 = n1
    batch_size = N1 + N2 # not using batch 
    n_epoch_c2st = 1000
    
    # Repeat experiments K times (K = 10) and report average test powers
    stats_a = []
    stats_d = []
    stats_p = []
    
    for kk in range(K):
        print('='*100)
        print("\t\t\t\tImbalance Ratio: {}".format(int(N1/N2)))
        print(f"\t\t\t\tExperiments{kk+1}")
        print('='*100)
        # Generate Blob-D
        np.random.seed(seed=112*kk + 1 + N1)
        s1, s2 = sample_blobs_Q(N1, N2, sigma_mx2)
        
        if kk == 0:
            s1_o = s1
            s2_o = s2
        
        S = np.concatenate((s1,s2), axis=0)
        S = MatConvert(S, device, dtype)
        
        # Train C2ST-L
        np.random.seed(seed=1203)
        torch.manual_seed(1203)
        torch.cuda.manual_seed(1203)
        y = (torch.cat((torch.zeros(N1, 1), torch.ones(N2, 1)), 0)).squeeze(1).to(device, dtype).long()
        cutvals = np.linspace(0.001, 0.999, 1000)
        pred, tau0, tau1, stat_c2st = c2st_nn_power(S, y, x_in, H, x_out, 0.01, n_epoch_c2st, batch_size, device, dtype)

# %%
# For each n in n_list, train deep kernel and run two-sample test

stats = {}
powers = []
for n in n_list:
    np.random.seed(12203)
    torch.manual_seed(12203)
    torch.cuda.manual_seed(12203)
    N1 = 30 * n
    N2 = 300
    results = np.zeros([5, K])
    J_star_adp = np.zeros([K, n_epoch])
    batch_size = N1 + N2 
    n_epoch_c2st = 500
    
    # Repeat experiments K times (K = 10) and report average test power 
    stat = []
    for kk in range(K):
        print("Imbalance Ratio: {}".format(N1/N2))
        print(f"{kk+1} Experiments...")
        
        # Generate Blob-D
        np.random.seed(seed=112*kk + 1 + n)
        s1, s2 = sample_blobs_Q(N1, N2, sigma_mx2)
        
        if kk == 0:
            s1_o = s1
            s2_o = s2
        
        S = np.concatenate((s1,s2), axis=0)
        S = MatConvert(S, device, dtype)
        
        # Train C2ST-L
        np.random.seed(seed=12203)
        torch.manual_seed(12203)
        torch.cuda.manual_seed(12203)
        y = (torch.cat((torch.zeros(N1, 1), torch.ones(N2, 1)), 0)).squeeze(1).to(device, dtype).long()
        pred, tau0, tau1, stat_c2st_l, model_c2st_l, w_c2st_l, b_c2st_l = C2ST_NN_power(S, y, N1, x_in, H, x_out, 0.0005, 
                                                                          n_epoch_c2st, batch_size, device, dtype)
        # statistics
        stat.append(stat_c2st_l)
        print(pred.unique(return_counts=True))
        print(f"tau0: {tau0} \t tau1: {tau1} ", end='\t')
        print("Stats: {}".format(stat_c2st_l))
        stats[n] = stat
        
    # power
    pwr = len([i for i in stats[n] if i > (1-norm.ppf(alpha))]) / len(stats[n])
    powers.append(pwr)
    print("Power: {}".format(pwr))
    print("="*50)

# %%
stats

# %%
tau1

# %%
stat_c2st_l

# %%
pred.unique(return_counts=True)

# %%
stats

# %%
batch_size = 32

df = sample_blobs_Q(500, 500, sigma_mx2)

# %%
# Generate data
data = sample_blobs_Q(n0=500, n1=500, sigma_mx_2=sigma_mx2)

# Split data into training and test sets
train_data = data.sample(frac=0.8, random_state=42)
test_data = data.drop(train_data.index)

# Convert data to PyTorch tensors
train_x = torch.tensor(train_data.iloc[:, :-1].values, dtype=torch.float32)
train_y = torch.tensor(train_data.iloc[:, -1].values, dtype=torch.int64)
test_x = torch.tensor(test_data.iloc[:, :-1].values, dtype=torch.float32)
test_y = torch.tensor(test_data.iloc[:, -1].values, dtype=torch.int64)

# Define the LeNet model
model = LeNet()

# Define the optimizer and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = torch.nn.CrossEntropyLoss()

# Train the model
num_epochs = 10
for epoch in range(num_epochs):
    # Shuffle the training data
    indices = torch.randperm(train_x.shape[0])
    train_x = train_x[indices]
    train_y = train_y[indices]
    
    # Train the model for one epoch
    model.train()
    for i in range(0, train_x.shape[0], batch_size):
        # Get the current batch of training data
        x = train_x[i:i+batch_size].reshape(-1, 1, 2, 1)
        y = train_y[i:i+batch_size]
        
        # Zero the gradients
        optimizer.zero_grad()
        
        # Forward pass
        y_pred = model(x)
        loss = loss_fn(y_pred, y)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()

# %%
# X_train, X_test, y_train, y_test = train_test_split(df.drop("class", axis=1), df["class"], test_size=0.5, random_state=42)
# X_train = torch.from_numpy(X_train.to_numpy().reshape(-1, 1, 3, 3)).float()
# y_train = torch.from_numpy(y_train.to_numpy()).float()
# X_test = torch.from_numpy(X_test.to_numpy().reshape(-1, 1, 3, 3)).float()
# y_test = torch.from_numpy(y_test.to_numpy()).float()

# %%
model = LeNet()
optimizer = optim.Adam(model.parameters(), lr = 0.001)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size)

# %%
num_epochs = 10
criterion = nn.CrossEntropyLoss()
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
    print(f"Epoch {epoch+1}, loss: {running_loss/len(train_loader)}")

# %%
# set up training parameters
learning_rate = 0.001
num_epochs = 10
batch_size = 128

# define the loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# train the model
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        # inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels.float())
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print('[Epoch %d] Loss: %.3f' % (epoch + 1, running_loss / len(train_loader)))

# predict on the test set
model.eval()
y_pred = []
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        y_pred.append(outputs.detach().cpu().numpy().flatten())
y_pred = np.concatenate(y_pred)

# compute power function
tau_0 = np.mean(y_test[y_test == 0])
tau_1 = np.mean(y_test[y_test == 1])
n0 = len(y_test[y_test == 0])
n1 = len(y_test[y_test == 1])
sigma_mx_2 = get_sigma_mx2(n0, n1, y_test, y_pred)
se = np.sqrt(tau_1*(1-tau_1)/n1 + tau_0*(1-tau_0)/n0)
power = norm.cdf((norm.ppf(0.8) - se*np.sqrt(sigma_mx_2.sum()))/np.sqrt(sigma_mx_2.sum()))
print('Power:', power)
